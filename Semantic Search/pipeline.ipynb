# %% [markdown]
# # Objectives
#
# This notebook will show a pipeline to do the following:
# 1. Cluster articles by similarity - will focus mainly on perfect matches to group syndicated content
# 2. Semantic search for a given set of key words
# 3. Ad prediction
# 4. Augmentations:
#     * Article summarization
#     * Article sentiment (overall)
#
# The result will be a sorted list of articles, grouped by key word search.  This will serve as an example of replacing the current search results.

# %%
import re
import pickle
import pandas as pd
import numpy as np
import tensorflow as tf
from simhash import Simhash, SimhashIndex
from itertools import combinations_with_replacement
from collections import defaultdict
from scipy.sparse import coo_matrix
from scipy.sparse.csgraph import connected_components
from haystack import Pipeline
from haystack.utils import print_documents
from haystack.nodes import (
    PreProcessor,
    DensePassageRetriever,
    SentenceTransformersRanker,
)
from haystack.document_stores import FAISSDocumentStore
from tensorflow import keras
from keras.models import model_from_json
from tensorflow.keras.layers import TextVectorization, Embedding, Dense, Lambda
from xgboost import XGBClassifier
# Out:
# INFO - haystack.modeling.model.optimization -  apex not found, won't use it. See https://nvidia.github.io/apex/

# %%
def get_features(s: str, width: int=3) -> list:
    """
    Returns list of substrings of a given width.  Example: 'how are' -> ['how', 'owa', 'war', 'are']
    
    :param s: String to parse
    :param width: Length of the sliding window.  The default, 3, results in 1 character on each side of 
        each characters position.  
    """
    s = s.lower()
    s = re.sub(r'[^\w]+', '', s)
    return [s[i:i + width] for i in range(max(len(s) - width + 1, 1))]


def hash_and_index_documents(docs: pd.DataFrame, text_col: str, distance_threshold: int=1):
    """
    Use SimHash to hash the documents and index them for efficient searching and distance calculation.
    
    :param docs: Dataframe of documents
    :param text_col: Name of the dataframe column with the document text
    :param distance_threshold: Hash distances > than this value will not be considered similar.  
        This value must be an integer.  The default, 1, limits similarity to exact matches.
    """
    docs_dict = docs[text_col].to_dict()
    hashes = [(str(k), Simhash(get_features(v))) for k, v in docs_dict.items()]
    index = SimhashIndex(hashes, k=distance_threshold)
    return (hashes, index)


def determine_clusters(index) -> dict:
    """
    The SimHash library does not have a way to determine clusters, so this function serves that 
    purpose.  The SimHash index.bucket is a dictionary whose keys are the hash keys and whose 
    values are lists of [hash, doc_id].  So by splitting these on commas and taking the second 
    element, it is possible to get a list of document Ids in the same bucket (cluster).
    
    :param index: SimHash index object
    """
    clusters = {}
    cluster_id = 0
    for simhash_key, hashes in index.bucket.items():
        similar_doc_ids = [int(hash_details.split(",")[1]) for hash_details in hashes]
        clusters[cluster_id] = set(similar_doc_ids)
        cluster_id += 1
    return clusters


def build_adjacency_matrix_from_clusters(clusters: dict, nbr_documents: int):
    """
    Given the clusters, build a square, sparse adjanceny matrix that shows which documents 
    are connected (documents are connected if they are in the same cluster).  
    
    :param clusters: The cluster dictionary from determine_clusters()
    :param nbr_documents: The total number of documents.  The matrix will have this many rows and columns.
    """
    # create a list of tuples representing the edges in a graph
    edges = set([(x, y) for c in clusters.values() for x, y in combinations_with_replacement(c, 2)])
    # create a square adjency matrix from the edge list
    matrix_shape = (nbr_documents, nbr_documents)
    rows, cols = zip(*edges)
    sparse_mat = coo_matrix((np.ones(len(edges)), (rows, cols)), shape=matrix_shape)
    return sparse_mat


def get_one_sample_text_per_cluster(df: pd.DataFrame, text_col) -> dict:
    """
    Clusters have similar texts, so take the first one per cluster to reduce the number of documents 
    that the similarity search has to run through.  Haystack expects the input to be a list of dictionaries 
    in the following format, which is what this function creates:
        [{'doc_id': 0, 'content': 'this is a document'}, {'doc_id': 1, 'content': 'this is another document'}]
    
    :param df: Dataframe with the texts
    :param text_col: Name of the column with the document text
    """
    grouped = df.groupby('cluster').first().rename(columns={text_col: 'content'})
    return grouped[['doc_id', 'content']].to_dict(orient='records')


def build_faiss_document_store(doc_list, haystack_processor, haystack_doc_store, haystack_retriever, save=True, save_path="haystack_doc_store.faiss"):
    """
    Runs the doc_list through Haystack's PreProcessor, writes the result to a FAISS document store, and 
    then updates the doc store with the embeddings from the provided retriever.  
    """
    documents = haystack_processor.process(doc_list)
    haystack_doc_store.write_documents(documents, duplicate_documents='overwrite')
    # embed the documents that have been indexed, using the embedding method defined in haystack_retriever
    haystack_doc_store.update_embeddings(haystack_retriever)
    if save:
        haystack_doc_store.save(save_path)
    return haystack_doc_store


def load_faiss_document_store(file_path):
    return FAISSDocumentStore.load(file_path)


def build_haystack_pipeline_for_semantic_search(retriever, ranker=None):
    """
    Builds a Haystack pipeline for semantic search. The ranker is optional, but it can help if the 
    sorted results of the retriever are inadequate - this is more of a problem with retrievers that 
    do not use embeddings, like TF-IDF and BM25/Elastic Search. 
    """
    p = Pipeline()
    p.add_node(component=retriever, name="Retriever", inputs=["Query"])
    if ranker:
        p.add_node(component=ranker, name="Ranker", inputs=["Retriever"])
    return p


def clean_search_term(s: str, lowercase=False) -> str:
    """
    Cleans the search term text
    """
    if lowercase:
        s = ' '.join(''.join(c.lower() for c in w if c.isalnum()) for w in s.split())
    else:
        s = ' '.join(''.join(c for c in w if c.isalnum()) for w in s.split())
    return s


def sum_layer(x):
    """
    Sum layer for the embedding model - allows aggregation from word to document level
    """
    return tf.reduce_sum(input_tensor=x, axis=0, keepdims=False)


def map_cluster_sample_doc_ids_to_ad_probability(cluster_samples: dict, pred_probs: np.ndarray) -> dict:
    """
    Creates dict mapping of the doc_ids in cluster_samples to their predicted ad probabilities.
    """
    ad_probs = {}
    for i, doc in enumerate(cluster_samples):
        ad_probs[doc['doc_id']] = pred_probs[i, 1]
    return ad_probs


def map_ad_probs_to_clusters(ad_probs: dict, doc_id_to_cluster_map: dict) -> dict:
    """
    Creates dict mapping of the cluster_ids to their predicted ad probabilities.  Since there 
    is 1 document per cluster in cluster_samples, the probability that that document is an ad 
    applies to the entire cluster.
    """
    cluster_ad_probs = {}
    for doc_id, ad_prob in ad_probs.items():
        cluster = doc_id_to_cluster_map[doc_id]
        cluster_ad_probs[cluster] = ad_prob
    return cluster_ad_probs

# %% [markdown]
# ## Data Ingestion and Hashing

# %%
# ingest and hash documents
blackwing_data = pd.read_csv('blackwing_3m_9k.csv')
blackwing_objs, index = hash_and_index_documents(
    docs=blackwing_data,
    text_col='text',
    distance_threshold=1
)
print(f"{len(blackwing_data)} documents hashed")
# Out:
# 8952 documents hashed

# %% [markdown]
# ## Consolidating Similar Docs

# %%
# get the cluster for each document
clusters = determine_clusters(index)
sparse_mat = build_adjacency_matrix_from_clusters(clusters=clusters, nbr_documents=len(blackwing_data))
nbr_clusters, cluster = connected_components(sparse_mat)
blackwing_data['cluster'] = cluster
blackwing_data = blackwing_data.reset_index(drop=False).rename(columns={'index':'doc_id'})
doc_id_to_cluster_map = dict(zip(blackwing_data['doc_id'], blackwing_data['cluster']))
print(f"{nbr_clusters} clusters found")
# Out:
# 420 clusters found

# %%
# all subsequent steps should operate on cluster_samples instead of entire dataset
cluster_samples = get_one_sample_text_per_cluster(df=blackwing_data, text_col="text")

# %% [markdown]
# ## Semantic Search

# %%
# create the components of the Haystack search pipeline

processor = PreProcessor(
    clean_empty_lines=True,
    clean_whitespace=True,
    clean_header_footer=True,
    split_by="word",
    split_length=200,
    split_respect_sentence_boundary=True,
    split_overlap=0
)

document_store = FAISSDocumentStore(
    similarity='dot_product',
    return_embedding=True,
    faiss_index_factory_str="Flat"
)

retriever = DensePassageRetriever(
    document_store=document_store,
    query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
    passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
    max_seq_len_query=64,
    max_seq_len_passage=256,
    batch_size=16,
    use_gpu=True,
    embed_title=True,
    use_fast_tokenizers=True,
)

ranker = SentenceTransformersRanker(
    model_name_or_path="cross-encoder/ms-marco-MiniLM-L-12-v2"
)
# Out:
# INFO - haystack.modeling.utils -  Using devices: CPU
# INFO - haystack.modeling.utils -  Number of GPUs: 0
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find facebook/dpr-question_encoder-single-nq-base locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# INFO - haystack.modeling.model.language_model -  Loaded facebook/dpr-question_encoder-single-nq-base
# The tokenizer class you load from this checkpoint is not the same type as the class this function is called from. It may result in unexpected tokenization.
# The tokenizer class you load from this checkpoint is 'DPRQuestionEncoderTokenizer'.
# The class this function is called from is 'DPRContextEncoderTokenizerFast'.
# INFO - haystack.modeling.model.language_model -  LOADING MODEL
# INFO - haystack.modeling.model.language_model -  =============
# INFO - haystack.modeling.model.language_model -  Could not find facebook/dpr-ctx_encoder-single-nq-base locally.
# INFO - haystack.modeling.model.language_model -  Looking on Transformers Model Hub (in local cache and online)...
# INFO - haystack.modeling.model.language_model -  Loaded facebook/dpr-ctx_encoder-single-nq-base
# INFO - haystack.modeling.utils -  Using devices: CPU
# INFO - haystack.modeling.utils -  Number of GPUs: 0

# %%
# build or load document store
document_store = build_faiss_document_store(
    doc_list=cluster_samples, 
    haystack_processor=processor, 
    haystack_doc_store=document_store, 
    haystack_retriever=retriever, 
    save=True, 
    save_path="haystack_doc_store.faiss"
)
# Out:
#   0%|          | 0/420 [00:00<?, ?docs/s]WARNING - haystack.nodes.preprocessor.preprocessor -  One or more sentence found with word count higher than the split length.
# 100%|██████████| 420/420 [00:00<00:00, 675.37docs/s]
# Writing Documents:   0%|          | 0/1946 [00:00<?, ?it/s]
# INFO - haystack.document_stores.faiss -  Updating embeddings for 1922 docs...
# Updating Embedding:   0%|          | 0/1922 [00:00<?, ? docs/s]
# Create embeddings:   0%|          | 0/1936 [00:00<?, ? Docs/s]

# %%
pipe = build_haystack_pipeline_for_semantic_search(retriever=retriever, ranker=None)

# %%
searches = blackwing_data['term'].apply(lambda x: clean_search_term(x)).tolist()
searches[0:20]
# Out:
# ['Long term care',
#  'General Electric',
#  'honeywell',
#  'Siemens AND AI',
#  'AI AND Healthcare',
#  'AI AND hospitals',
#  'Oracle AND AI',
#  'healthcare AND innovat',
#  'healthcare AND AI',
#  'pharma AND AI',
#  'Oracle AND data management NOT PRNewswire',
#  'healthcare AND trend',
#  'healthcare AND artificial intelligence',
#  'artificial intelligence AND healthcare',
#  'robots AND healthcare',
#  'innovation AND healthcare',
#  'telemedicine',
#  'EHR',
#  'electronic health record',
#  'longterm care']

# %%
# run a search
nbr_results_to_return = int(25) # need to limit results, otherwise all docs in corpus will be returned
result = pipe.run(
    query=searches[4],
    params={"top_k": nbr_results_to_return}
)
print_documents(result)
# Out:
# Query: AI AND Healthcare
#
# {   'content': 'The healthcare IT market is estimated to be worth $40 billion '
#                'with a 7-14% growth by the end of fiscal year 2024.MMM shares '
#                'were down more than 1% at $157.83 apiece near the close of '
#                'trading today similar to the performance of MassDevice and '
#                'MDO?s MedTech 100 Index....3M said it plans to prioritize '
#                'large fast-growing commercial markets in its 2022 growth '
#                'strategy including innovations in ......3M?s healthcare '
#                'segment expects organic sales growth to be in the ?mid-single '
#                'digits? for the year.',
#     'name': None}
#
# {   'content': 'The key industry participants include:Abbott Laboratories '
#                'Dr?gerwerk AG General Electric Company Honeywell International '
#                'Inc. Medtronic plc Oracle Corporation Siemens AG Allscripts '
#                'Healthcare Solutions Inc. AMD Global Telemedicine Inc. and '
#                'Carematix Inc.Global Wireless Electronic Health Records Market '
#                'Report - Segmental Analysis:The global Wireless Electronic '
#                'Health Records business vertical has been extensively '
#                'categorized on the basis of product type application gamut '
#                'end-user industries and a competitive overview. The report '
#                'inspects the current market scenario its past performance '
#                'demand and supply ratios production and consumption rates '
#                'sales and numerous growth opportunities available in the '
#                'market. It further estimates the prospective growth of the '
#                'leading regional segments of the market which is beneficial '
#                'for readers to gain impactful insights into the Wireless '
#                'Electronic Health Records business sector.',
#     'name': None}
#
# {   'content': 'Elevating demand for APIs to develop smarter applications the '
#                'increasing use of the service in the functioning of different '
#                'industries are some of the factors boosting the cognitive '
#                'services market.The global Cognitive Services Market is '
#                'forecast to reach USD 63.99 Billion by 2028 according to a new '
#                'report by Reports and Data. Cognitive services can be '
#                'considered as a part of artificial intelligence [AI] platform. '
#                'One of the mentionable benefits associated with the service is '
#                'the effective application of AI to various scenarios with a '
#                'comprehensive portfolio of domain-specific AI capabilities. '
#                'Most importantly the service is useful in making faster and '
#                'smarter decisions helping organizations to lead the market '
#                'competition. It is with the help of an anomaly detector; '
#                'potential issues may be detected on a prior hand based on '
#                'which strategic decisions can be taken to avoid the problem. '
#                'Thus the presence of these benefits are supporting the growth '
#                'of the market. In context to region Europe can be seen to '
#                'occupy a prominent market position.',
#     'name': None}
#
# {   'content': 'The report offers a holistic coverage of the Wireless '
#                'Electronic Health Records market laying emphasis on the key '
#                'factors influencing the industrial growth technological '
#                'developments taking place in the industry and current and '
#                'emerging trends witnessed in the leading regional marketsTo '
#                'receive a sample of the global Wireless Electronic Health '
#                'Records market report click here @ '
#                'https://www.emergenresearch.com/request-sample/865Key '
#                'Highlights From the ReportIn October 2020 KareXpert launched a '
#                'new integrated cloud-based platform with built-in EHR in '
#                'India. The new platform is expected to help healthcare '
#                'facilities in the country to go paperless. The new platform is '
#                'suited for Artificial Intelligence (AI) and has ability to '
#                'support patients nurses and doctors on mobile and desktop '
#                'devices by compiling data involving medication administration '
#                'requests computerized physician order entry and patient health '
#                'records. The platform has the potential to support '
#                'multi-facility location hospitals to have integrated EHR per '
#                'patient on a real-time basis.Wireless electronic health '
#                'records devices segment accounted for largest revenue share in '
#                '2020.',
#     'name': None}
#
# {   'content': 'The vaccine also appeared to result in a robust immune '
#                'response detected through antibodies and other immune-related '
#                'substances in the body.Curevo injection is made from a '
#                'non-living component of the virus and a proprietary adjuvant a '
#                'substance that is added to the injection to increase the '
#                'effectiveness of the vaccine.Curevo was established in 2018 as '
#                'a partnership between the South Korean company GC Pharma; the '
#                'Mogam Institute for Biomedical Research a global nonprofit '
#                'research organization based in Seoul; and the Seattle '
#                'Infectious Disease Research Institute (IDRI). GC Pharma has '
#                'the ability to manufacture vaccines at scale and IDRI is known '
#                'for its adjuvant technology.founder of IDRI steve cane he is '
#                'an executive director and director of Curevo; he also serves '
#                'as CEO of HDT Bio a Seattle company developing a globally '
#                'accessible COVID-19 vaccine. CEO of Curevo George Simeon He '
#                'previously worked in South Korea for SK Telecom?s healthcare '
#                'division and as an executive at Johnson & Johnson.Curevo may '
#                'also face competition from COVID-19 vaccine makers Pfizer and '
#                'BioNTech; the companies recently announced a partnership to '
#                'also develop a shingles vaccine.',
#     'name': None}
#
# {   'content': 'there are other classes of highly potent APIs such as hormones '
#                'narcotics and retinoids.Advances in HPAPI manufacturing '
#                'technologies are also contributing to the expansion of the '
#                'market. In particular antibody-drug conjugates (ADCs) are now '
#                'the fastest growing segment of the HPAPI market because they '
#                'enable the delivery of cytotoxic drugs to targeted cells. '
#                'Composed of antibodies ADCs are designed to bind to specific '
#                'antigen-expressing cells (e.g. tumour cells) that are linked '
#                'to highly potent small-molecule APIs (payloads). The linker is '
#                'designed to release the payload only once the antibody reaches '
#                'the targeted cells.Growth of the HPAPI market is also in part '
#                'fuelled by desire in the industry to adopt the safest '
#                'approaches to manufacturing APIs and formulated drug products.',
#     'name': None}
#
# {   'content': 'Epigenetics Market Size Key Factors Major Players Growth '
#                'Strategies Trends Forecast Till 2028According to the current '
#                'analysis of Reports and Data the global Epigenetics market was '
#                'valued at USD 9143.1 Million in 2020 and is expected to reach '
#                'USD 36.52 Billion by 2028 at a CAGR of 18.8%. Epigenetics '
#                'refers to changes in gene activity without altering the DNA '
#                'sequence the changes being transmittable to daughter cells. '
#                'Epigenetic processes are natural and essential for the '
#                'functioning of many organisms but odd occurrences can prove to '
#                'be a source of various disorders including different kinds of '
#                'cancers reproductive illnesses cardiovascular illnesses etc. '
#                'In addition to this behavioral changes and changes in mental '
#                'state are also observed on account of epigenetic '
#                'changes.Several illnesses and other health indicators may have '
#                'direct or indirect link with epigenetic mechanisms including '
#                'various cancers respiratory diseases cardiovascular diseases '
#                'reproductive complications autoimmune disorders and cognitive '
#                'dysfunction ailments.',
#     'name': None}
#
# {   'content': 'For instance an epigenetic biotechnology company - EpigenCare '
#                'completed its initial pilot study in 2019 with its '
#                'direct-to-consumer epigenetic skincare test as part of its '
#                'beta phaseKey Companies in the market include:Illumina Thermo '
#                'Fisher Scientific Merck Millipore Abcam Active Motif Bio-Rad '
#                'Laboratories among others that collectively constitute a '
#                'competitive marketMarket segment analysis:Product Type Outlook '
#                '(Revenue in USD Million; 2018?2028)ReagentsKitsChip sequencing '
#                'kitWhole Genomic Amplification kitBisulfite Conversion kitRNA '
#                'sequencing kitOthersInstrumentsEnzymesServicesTechnology '
#                'Outlook (Revenue in USD Million; 2018?2028)DNA '
#                'MethylationHistone MethylationHistone AcetylationLarge non - '
#                'coding RNAMicroRNA modificationChromatin structuresApplication '
#                'Outlook (Revenue in USD Million; 2018?2028)OncologySolid '
#                'tumors Liquid tumorsNon - oncologyInflammatory '
#                'diseasesMetabolic diseasesInfectious diseasesCardiovascular '
#                'diseasesOthersEnd Use Outlook (Revenue in Million USD; '
#                '2018?2028)Academic and Research InstitutesPharmaceutical and '
#                'Biotechnology CompaniesContract Research Organizations '
#                '(CROs)Regional analysis further covers a country-wise analysis '
#                'to offer insights into key trends and demands in each major '
#                'country that might affect the growth of the market in the '
#                'region.North AmericaEuropeGermanyUK.ItalyFranceBENELUXRest of '
#                'EuropeAsia PacificChinaIndiaJapanSouth KoreaRest of APACLatin '
#                'AmericaMiddle East & AfricaSaudi ArabiaA.E.South AfricaRest of '
#                'MEARequest a customization of the report @ '
#                'https://www.reportsanddata.com/request-customization-form/2079Thank '
#                'you for reading the report. The report can be customize as per '
#                'requirements of the clients.',
#     'name': None}
#
# {   'content': 'For further information or query about customization please '
#                'reach out to us and we will offer you the report best suited '
#                'for your needs.Browse More Reports :Protein Kinase Inhibitors '
#                'Market Growth RateLiver Detox Market TrendsOrthopedic Surgical '
#                'Power Tools Market StatisticsInduced Pluripotent Stem Cells '
#                'Market ResearchPharmaceutical Drug Delivery Market Growth '
#                'RateTags: Epigenetics Market Epigenetics Market trends '
#                'Epigenetics Market analysis Epigenetics Market Size '
#                'Epigenetics Market Forecast Epigenetics Market ShareSee '
#                'Campaign: '
#                'https://www.reportsanddata.com/report-detail/epigenetics-marketContact '
#                'Information:Contact Us:John WHead of Business '
#                'DevelopmentReports And Data | Web:www.reportsanddata.comDirect '
#                'Line: '
#                '+1-212-710-1370E-mail:sales@reportsanddata.comLinkedIn|Twitter|BlogsTags:ReportedtimesPR-WireiniCN '
#                'Internal DistributionResearch NewswireEnglish...Epigenetics '
#                'Market Size Key Factors Major Players Growth Strategies Trends '
#                'Forecast Till 2028 A',
#     'name': None}
#
# {   'content': 'A clear outline of the competitive landscape of the market is '
#                'expected to help businesses involved in this sector decipher '
#                'the optimal business moves to reach their desired business '
#                'goals.Emergen Research has segmented the global wireless '
#                'electronic health records market on the basis of type '
#                'application end-use specialty mobile technologies and '
#                'region:Type Outlook (Revenue USD Billion; 2018?2028)Wireless '
#                'Electronic Health Records SoftwareWireless Electronic Health '
#                'Records DevicesApplication Outlook (Revenue USD Billion; '
#                '2018?2028)AdministrationPharmacyClinicalRadiologyNursingLaboratoryEnd-use '
#                'Outlook (Revenue USD Billion; 2018?2028)Long-term Care '
#                'FacilitiesPhysician OfficesHospitalsOthersSpecialty Outlook '
#                '(Revenue USD Billion; '
#                '2018?2028)NeurologyCardiologyUrologyOrthopedicPediatricsOphthalmologyOncologyGeneral '
#                'SurgeryObstetrics and GynecologyOthersMobile Technologies '
#                'Outlook (Revenue USD Billion; 2018?2028)Commercial '
#                'CellularWireless LANsBluetoothRadio Frequency Identification '
#                '(RFID)SatellitesZigbeeWiMAXOthersKey Geographies Profiled in '
#                'the Report:North America(the U.S. Mexico and Canada)Asia '
#                'Pacific(China Japan India and Rest of Asia Pacific)Europe(the '
#                'U.K. France Germany and Rest of Europe)Latin America(Brazil '
#                'and Rest of Latin America)Middle East & Africa(GCC Countries '
#                'and Rest of Middle East & Africa)Request customization of the '
#                'market report @ '
#                'https://www.emergenresearch.com/request-for-customization/865Key '
#                'Objectives of the Global Wireless Electronic Health Records '
#                'Market Report:An all-inclusive analysis and forecast '
#                'estimation of the market have been included in this report.The '
#                'report offers valuable insights into the major drivers '
#                'limitations opportunities and challenges faced by the global '
#                'Wireless Electronic Health Records market and its leading '
#                'players.The report sheds light on the prominent market '
#                'contenders as well as their business strategies and long-term '
#                'expansion plans.The report additionally presents a '
#                'comprehensive analysis of the key elements of the Wireless '
#                'Electronic Health Records market that influence its growth '
#                'over the projected timeline.',
#     'name': None}
#
# {   'content': 'The growth of the eCommerce sector and technological '
#                'advancement contributes to the growth of the market in this '
#                'region.To identify the key trends in the industry click on the '
#                'link below: '
#                'https://www.reportsanddata.com/report-detail/cognitive-services-marketFor '
#                'the purpose of this report Reports and Data have segmented the '
#                'global cognitive services market based on Service Type '
#                'Technology Organization Size Deployment Mode Application '
#                'End-user and region:Service Type Outlook (Revenue USD Billion; '
#                '2020-2028)Data TransformationCloud and Web-Based Application '
#                'Programming InterfaceKnowledge ManagementCognitive Risk '
#                'IntelligenceData Integration and Cognitive AutomationTraining '
#                'and SupportCommunication MonitoringConsulting and '
#                'AdvisoryOthersTechnology Type Outlook (Revenue USD Billion; '
#                '2020-2028)Natural Language ProcessingMachine Learning and Deep '
#                'LearningOrganization size Type Outlook (Revenue USD Billion; '
#                '2020-2028)Large EnterprisesSmall and Medium-Sized '
#                'EnterprisesDeployment Mode Type Outlook (Revenue USD Billion; '
#                '2020-2028)On-PremisesCloudApplication Type Outlook (Revenue '
#                'USD Billion; 2020-2028)Predictive MaintenanceMarketing '
#                'AnalysisQuality Management Investigation and '
#                'RecommendationSupply Chain ManagementDiagnosis and Treatment '
#                'SystemSafety and Security ManagementOthersEnd-user Type '
#                'Outlook (Revenue USD Billion; 2020-2028)HealthcareBanking '
#                'Financial Services and InsuranceIT and '
#                'TelecommunicationRetailManufacturingEducationGovernmentOthersRegional '
#                'Outlook (Revenue USD Billion; 2020-2028)North '
#                'AmericaEuropeAsia PacificMEALatin AmericaRequest a '
#                'customization of the report @ '
#                'https://www.reportsanddata.com/request-customization-form/2552Market '
#                'Report includes major TOC points:Cognitive Services market '
#                'OverviewGlobal Economic Impact on IndustryGlobal Market '
#                'Competition by ManufacturersGlobal Production Revenue (Value) '
#                'by RegionGlobal Supply (Production) Consumption Export Import '
#                'by RegionsGlobal Production Revenue (Value) Price Trend by '
#                'TypeGlobal Market Analysis by ApplicationManufacturing Cost '
#                'AnalysisIndustrial Chain Sourcing Strategy and Downstream '
#                'BuyersMarketing Strategy Analysis Distributors/TradersMarket '
#                'Effect Factors AnalysisCognitive Services market '
#                'ForecastConclusively all aspects of the Cognitive Services '
#                'market are quantitatively as well qualitatively assessed to '
#                'study the global as well as regional market comparatively.',
#     'name': None}
#
# {   'content': 'The Advanced Process Control (APC) Software market report '
#                'meticulously assesses this industry vertical to aid '
#                'stakeholders take better decisions and subsequently expand '
#                'their business portfolio in the approaching years. The '
#                'document emphasizes on predominant trends and lucrative '
#                'prospects that can help generate substantial returns. Besides '
#                'it recommends the best practices and solutions which can be '
#                'adopted by industry partakers to face the existing and '
#                'upcoming challenges.',
#     'name': None}
#
# {   'content': 'Wireless Electronic Health Records Market Recent Trends Future '
#                'Growth Industry Analysis Outlook Insights Share and Forecasts '
#                'Report 2028The global wireless Electronic Health Records '
#                '(EHRs) market size is expected to reach USD 91.72 Billion in '
#                '2028 and register a steady CAGR over the forecast period '
#                'according to latest analysis by Emergen Research. Market '
#                'revenue growth is primarily driven by increasing deployment '
#                'and use of more advanced technologies and devices to enhance '
#                'treatment quality and efficiency in tracking clinical '
#                'information of patients. Benefits obtained by deploying '
#                'wireless EHRs include reduced medical errors improved patient '
#                'care and safety and reduction in healthcare costs. Connected '
#                'EHRs over secure wireless or the Internet enable remote access '
#                'to medical records via satellite sites or even from home. '
#                'Convenience and quick access to patient information by '
#                'authorized healthcare personnel to enable faster response and '
#                'enhanced treatment are other key factors expected to boost '
#                'revenue growth of the market during the forecast period.Mobile '
#                'electronic health records on iOS and Android devices are one '
#                'of the growth areas in the wireless electronic health record '
#                'market.',
#     'name': None}
#
# {   'content': 'Accessing an electronic health record via mobile device such '
#                'as smartphone or tablet helps in improving efficiency of '
#                'inpatient medical care by facilitating earlier order entry and '
#                'decreases inpatient data management time. Adoption of these '
#                'solutions continues to increase and is being deployed by an '
#                'increasing number of hospitals and healthcare centers and the '
#                'trend is expected to continue over the forecast '
#                'period.Wireless Electronic Health Records Market can be '
#                'considered a profound analysis of the global Wireless '
#                'Electronic Health Records industry that focuses on crucial '
#                'data and information pertaining to the sales and revenue '
#                'shares. The market evaluations over the forecast years are '
#                'based on a comprehensive analysis of the leading market '
#                'segments such as product type outlook application continuum '
#                'regional overview and competitive landscape of the global '
#                'Wireless Electronic Health Records market.',
#     'name': None}
#
# {   'content': 'The biosimilars market report identifies top countries and '
#                'segments for opportunities and strategies based on market '
#                'trends and key competitors? approaches.TBRC?s Biosimilars '
#                'Global Market Report 2022 includes information on the '
#                'following:Data Segmentations: Market Size Global By Region and '
#                'Country Historic and Forecast and Growth Rates for 60 '
#                'GeographiesKey Market Players: Pfizer Amgen Biocon Celltrion '
#                "Dr. Reddy's Laboratories Boehringer Ingelheim Elli Lilly and "
#                'Company Mylan N.V. Sanofi STADA Arzneimittel Sandoz '
#                'International Samsung Bioepis Teva Pharmaceuticals Apotex '
#                'AMEGA Biotech S.A. Bioton S.A. Innovent Biologics '
#                'International Allergan plc BioXpress Therapeutics 3SBio Intas '
#                'Biopharmaceuticals Lupin Merck Novartis Ratiopharm Wockhardt '
#                'Zydus Cadila Allergan Plc. Hospira International. Actavis '
#                'International. Johnson & Johnson and Roche.Regions: '
#                'Asia-Pacific China Western Europe Eastern Europe North America '
#                'USA South America Middle East and Africa.Countries: Australia '
#                'Brazil China France Germany India Indonesia Japan Russia South '
#                'Korea UK USA.And so much more.About The Business Research '
#                'CompanyThe Business Research Company has published over 1000 '
#                'industry reports covering over 2500 market segments and 60 '
#                'geographies. The reports draw on 150000 datasets extensive '
#                'secondary research and exclusive insights from interviews with '
#                'industry leaders.',
#     'name': None}
#
# {   'content': 'The market position held by the region is resultant of the '
#                'continuous growth of the eCommerce industry and healthcare '
#                'sector.Key participants include Microsoft IBM AWS Google '
#                'Nuance Communications Baidu SAS Qualcomm Technologies Nokia '
#                'TCS and Apple.Get a sample of the report @ '
#                'https://www.reportsanddata.com/sample-enquiry-form/2552Further '
#                'key findings from the report suggestThe cognitive services '
#                'market held a market share of USD 5306.6 Million in the year '
#                '2020 and forecasted to grow at a rate of 35.8% during the '
#                'forecast period.In regards to Technology the Natural Language '
#                'Processing segment generated a higher revenue of USD 1.83 '
#                'Billion in 2020 with a growth rate of 39.0% during the '
#                'forecast period. The extensive application of the technology '
#                'in the functioning of this service wherein it is required to '
#                'perceive read human languages and contribute in the '
#                'communication with the computer results in the revenue '
#                'generated by the segment.In context to Deployment Mode the '
#                'Cloud segment is projected to witness a faster CAGR of 41.3% '
#                'during the forecast period which is expected to occupy 70.0% '
#                'of the market by 2028.',
#     'name': None}
#
# {   'content': 'Several funding and R&D initiatives are undertaken by private '
#                'institutions and biopharmaceutical companies for the detection '
#                'of a biomarker for drug development and disorder are driving '
#                'the market growth. Also the growth of the geriatric population '
#                'in regions around the world is expected to endorse the growing '
#                'market. However the high initial cost and maintenance costs of '
#                'the instruments prove to be a significant hindrance to market '
#                'growth. Incidences like the shortage of trained professionals '
#                'and concerns regarding the quality of antibodies are '
#                'substantial challenges for the epigenetics market.View '
#                'Exhaustive Market Research Report '
#                '@https://www.reportsanddata.com/report-detail/epigenetics-marketThe '
#                'report includes descriptive profiles of major companies which '
#                'consists of the legal names headquarters website market '
#                'standing historical development and top 5 closest competitors '
#                'derived by inspecting their gross revenue along with contact '
#                "information. Every company's growth rate gross revenue and "
#                'profit margin have also been discussed in the study. It also '
#                'assesses other expansion tactics implemented by leading '
#                'companies including mergers acquisitions and product '
#                'launches.Grab Your Report at an Impressive Discount! Please '
#                'Click Here '
#                '@https://www.reportsanddata.com/discount-enquiry-form/2079Further '
#                'key findings from the report suggestReagents like antibodies '
#                'PCR reagents histones primers magnetic beads electrophoresis '
#                'reagents nucleic acid analysis reagents and buffers are '
#                'extensively used for epigenetic studies.',
#     'name': None}
#
# {   'content': 'Yet the tantalizing promise of one (or more) Covid-19 vaccines '
#                'is giving the markets a sense of real optimism.Things are '
#                'changing fast and that?s likely to continue into 2021. Whether '
#                'you?re an optimist or a pessimist you should take this time to '
#                'take a realistic look at your portfolio. With that in mind '
#                'let?s take a look at how the election may affect different '
#                'market sectors.Vaccine Stocks Will Remain VolatileOn November '
#                '9 Pfizer (NYSE:PFE) and BioNTech (NASDAQ:BNTX) announced that '
#                'the partnership?s Covid-19 vaccine candidate had achieved over '
#                '90% effectiveness in its Phase 3 trial. A week later Moderna '
#                '(NASDAQ:MRNA) announced a 95% effectiveness rate for its '
#                'vaccine candidate. And it appears that AstraZeneca '
#                '(NASDAQ:AZN) and Johnson & Johnson (NYSE:JNJ) may not be far '
#                'behind.Does this mean the race is over? Not quite. The Biden '
#                'administration has stated that ?defeating? the virus is its '
#                'top priority. That means that vaccine stocks are likely to '
#                'remain the object of investors? eyes.Plus the devil of the '
#                'vaccine will be in the details. The Pfizer and Moderna '
#                'vaccines are based on mRNA technology. I?m not downplaying '
#                'this. It?s actually really exciting. However it?s also '
#                'unproven outside of the clinical trials.',
#     'name': None}
#
# {   'content': 'can help but drug companies should only consider partnering '
#                'with firms that have a history of successfully producing and '
#                'handling HPAPIs and continually investing in the most advanced '
#                'safety equipment systems and processes.Highly potent market '
#                'growthHighly potent small-molecule and biologic drugs are '
#                'typically considered to be those APIs that have an '
#                'occupational exposure limit (OEL) of ?10g/m3 of air as an '
#                '8-hour time-weighted average. Many candidates under '
#                'development today have significantly lower OELs. They are '
#                'attractive in part because they require relatively low doses '
#                'which translates to reduced exposure to impurities.Those that '
#                'can be delivered in a highly targeted fashion are even more '
#                'desirable because they minimise unwanted side-effects and '
#                'allow for the use of highly potent compounds that otherwise '
#                'would cause too much damage to healthy cells. Grand View '
#                'Research1 estimates that the HPAPI market will increase '
#                'significantly from US$12bn in 2014 to $25.86bn in 2022 which '
#                'corresponds to an average annual growth rate of 14.4%.While '
#                'the majority of highly potent drugs under development are '
#                'oncology treatments ? and growth in this segment has been a '
#                'key driver for HPAPI market expansion ?',
#     'name': None}
#
# {   'content': 'Curevo is also developing a chickenpox vaccine that is '
#                'entering Phase 1 clinical studies in South Africa.The Series A '
#                'round was led by RA Capital Management. Other investors '
#                'include Adjuvant Capital Janus Henderson Investors EN '
#                'Investment and founding investor GC Pharma....Curevo CEO '
#                'George Simeon. (Curved Photo) curvy has raised $60 million to '
#                'develop a new vaccine again',
#     'name': None}
#
# {   'content': '31-Mar-2016As competition grows in highly potent active '
#                'pharmaceutical ingredients (HPAPI) manufacturing Arto Toivonen '
#                'President of Finnish API manufacturer Fermion considers key '
#                'factors that can ensure the successful outsourcing of '
#                'projectsAdvanced technologies that allow the delivery of drug '
#                'substances directly to the site of action ? tumour cells '
#                'infected cells damaged organs ? rather than acting '
#                'systemically are leading to drugs with increased safety and '
#                'efficacy. This approach also enables the use of highly potent '
#                'active pharmaceutical ingredients (HPAPIs) that previously '
#                'were not reasonable candidates due to their toxicity to the '
#                'patient when delivered using conventional '
#                'approaches.Pharmaceutical manufacturers are in need of '
#                'capacity suitable for the safe production storage and '
#                'transport of a growing range of potent compoundsConsequently '
#                'the HPAPI market is growing faster than the overall API market '
#                'and the percentage of drug candidates classified as HPAPIs is '
#                'increasing. Pharmaceutical manufacturers are in need of '
#                'capacity suitable for the safe production storage and '
#                'transport of a growing range of potent compounds. Contract '
#                'service providers ? both contract development and '
#                'manufacturing organisations (CDMOs) and CMOs ?',
#     'name': None}
#
# {   'content': 'We are a growing market research and strategy consulting '
#                'company with an exhaustive knowledge base of cutting-edge and '
#                'potentially market-disrupting technologies that are predicted '
#                'to become more prevalent in the coming decade.Tags: Wireless '
#                'Electronic Health Records Market growth Wireless Electronic '
#                'Health Records Market size Wireless Electronic Health Records '
#                'Market types Wireless Electronic Health Records Market '
#                'shareSee Campaign: '
#                'https://www.emergenresearch.com/industry-report/wireless-electronic-health-records-marketContact '
#                'Information:Contact Us:Eric LeeCorporate Sales '
#                'SpecialistEmergen Research | Web: '
#                'www.emergenresearch.comDirect Line: +1 (604) 757-9756E-mail: '
#                'sales@emergenresearch.comVisit for More Insights: '
#                'https://www.emergenresearch.com/insightsExplore Our Custom '
#                'Intelligence services | Growth Consulting '
#                'ServicesTags:MenafnReportedtimesPR-WireiniCN Internal '
#                'DistributionResearch NewswireEnglish',
#     'name': None}
#
# {   'content': 'This contribute to high market share of the reagents segment '
#                'in the epigenetics marketThe histone methylation segment is '
#                'expected to reach USD 5.65 billion by the year 2026 showing '
#                'significant growth of 13.1% during the forecast periodThe '
#                'emergence of epigenetic targets for the development of '
#                'epigenetic drugs and epigenetic therapy is expected to have a '
#                'highly positive impact on the epigenetics market. Leading '
#                'market players across the globe are investing significantly '
#                'towards product development for epigenetics based '
#                'applications. For instance in April 2019 GGC launched its '
#                'EpiSign a novel clinical test for analysis of epigenetic '
#                'changes.The European segment is expected to show a CAGR of '
#                '12.8% owing to increased investments in healthcare projects. '
#                'For instance project BLUEPRINT which aims at generating 100 '
#                'reference epigenomes of healthy and leukemic cells received a '
#                'funding of 52.1 million USD.Market players are adapting '
#                'various organic and inorganic expansion strategies. For '
#                'instance 10x Genomics a key player in genomics field acquired '
#                'Epigenomics a market player operating in epigenetics sector '
#                'and merged their epigenetic technology with its chromium '
#                'single-cell solution.Leading as well as emerging market '
#                'players are involved in various research and development '
#                'activities.',
#     'name': None}
#
# {   'content': 'Moreover macroeconomic factors and administrative procedures '
#                'are discovered explanations in Advanced Process Control (APC) '
#                'Software industry advancement and perceptive '
#                'examination.Assembling Analysis ?The Advanced Process Control '
#                '(APC) Software report is presently broken down concerning '
#                'different types and applications.',
#     'name': None}
#
# {   'content': "Kristine Grow a spokesperson for America's Health Insurance "
#                'Plans said in an email.She noted that ?there has been dramatic '
#                'growth in the use of behavioral health services? since '
#                'enactment of the 2008 parity law citing an analysis by FAIR '
#                'Health a consumer nonprofit that found the number of private '
#                'insurance claims for behavioral health diagnoses Blue Cross '
#                'Blue Shield Association is ?committed to complying with the '
#                'law? Kris Haltmeyer vice president for policy analysis said in '
#                'a statement. ?Patients deserve comprehensive health care that '
#                'effectively addresses their physical mental and social '
#                'well-being. ?Several big cases have recently gone against the '
#                'industry especially its largest and most profitable player. '
#                'UnitedHealth Group agreed in August to pay $15.6 million and '
#                'to revise its policy nationwide to settle a case against its '
#                'behavioral health unit.Plaintiffs in the class action argued '
#                'that United slashed out-of-network reimbursement rates for '
#                'psychologists by 25 percent and for social workers by up to 35 '
#                'percent compared with medical or surgical providers.',
#     'name': None}

# %% [raw]
# # example with pre-built doc store
# document_store_b = load_faiss_document_store(file_path="haystack_doc_store.faiss")
#
# retriever_b = DensePassageRetriever(
#     document_store=document_store_b,
#     query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
#     passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
#     max_seq_len_query=64,
#     max_seq_len_passage=256,
#     batch_size=16,
#     use_gpu=True,
#     embed_title=True,
#     use_fast_tokenizers=True,
# )
#
# pipe_b = build_haystack_pipeline_for_semantic_search(retriever=retriever_b, ranker=None)
#
# # run a search
# nbr_results_to_return = int(25) # need to limit results, otherwise all docs in corpus will be returned
# result_b = pipe_b.run(
#     query=searches[0],
#     params={"top_k": nbr_results_to_return}
# )
# print_documents(result_b)

# %% [markdown]
# ## Predicting Ads

# %%
# load a pre-trained vectorizer
pickled_vectorizer = pickle.load(open("ad_filter_vectorizer.pkl", "rb"))
vectorizer = TextVectorization.from_config(pickled_vectorizer['config'])
vectorizer.set_weights(pickled_vectorizer['weights'])
# vocab = vectorizer.get_vocabulary()

# %%
embedding_model = keras.models.load_model("ad_filter_embedding_model")
print("Loaded embedding model from disk")
# Out:
# WARNING:tensorflow:No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# WARNING - tensorflow -  No training configuration found in save file, so the model was *not* compiled. Compile it manually.
# Loaded embedding model from disk

# %%
model_file_path = "xgb_ad_classifier.pkl"
xgb_model = pickle.load(open(model_file_path, "rb"))

# %%
# note that ignore DOES NOT mean it is an ad, but it is an indication that it might be
blackwing_y = blackwing_data.disposition.map({"SELECT": 0, "IGNORE": 1})

# vectorize the documents
blackwing_test = [np.array(doc['content']) for doc in cluster_samples]

# embed the documents
blackwing_test = np.stack([embedding_model(doc).numpy() for doc in blackwing_test])

# make predictions
blackwing_pred = xgb_model.predict(blackwing_test)
blackwing_pred_prob = xgb_model.predict_proba(blackwing_test)

# %%
# get ad probabilities for clusters
ad_probs_of_doc_ids_in_cluster_samples = map_cluster_sample_doc_ids_to_ad_probability(
    cluster_samples=cluster_samples, 
    pred_probs=blackwing_pred_prob
)

cluster_ad_probs = map_ad_probs_to_clusters(
    ad_probs=ad_probs_of_doc_ids_in_cluster_samples, 
    doc_id_to_cluster_map=doc_id_to_cluster_map
)

cluster_ad_probs
# Out:
# {0: 0.9682984,
#  1: 0.28476533,
#  2: 0.36191425,
#  3: 0.7084052,
#  4: 0.8456159,
#  5: 0.8591308,
#  6: 0.75022084,
#  7: 0.08375392,
#  8: 0.009791594,
#  9: 0.118267186,
#  10: 0.31038052,
#  11: 0.0007375895,
#  12: 0.22928743,
#  13: 0.36704558,
#  14: 0.8738608,
#  15: 0.6519277,
#  16: 0.7881865,
#  17: 0.37217233,
#  18: 0.3882757,
#  19: 0.7747711,
#  20: 0.035497766,
#  21: 0.9571656,
#  22: 0.0853042,
#  23: 0.16937944,
#  24: 0.22529134,
#  25: 0.22861862,
#  26: 0.20061988,
#  27: 0.94811416,
#  28: 0.9461136,
#  29: 0.07775918,
#  30: 0.01388536,
#  31: 0.45798704,
#  32: 0.0071714646,
#  33: 0.6899225,
#  34: 0.64147544,
#  35: 0.18925129,
#  36: 0.328015,
#  37: 0.8245093,
#  38: 0.75209326,
#  39: 0.766727,
#  40: 0.8653293,
#  41: 0.82954305,
#  42: 0.53005713,
#  43: 0.4358212,
#  44: 0.4077822,
#  45: 0.5282003,
#  46: 0.65352255,
#  47: 0.99403304,
#  48: 0.14576975,
#  49: 0.8367934,
#  50: 0.95285016,
#  51: 0.8253634,
#  52: 0.7282593,
#  53: 0.55754507,
#  54: 0.530323,
#  55: 0.80354166,
#  56: 0.7567996,
#  57: 0.5516414,
#  58: 0.05337317,
#  59: 0.036768276,
#  60: 0.8814374,
#  61: 0.6858399,
#  62: 0.7816302,
#  63: 0.93665373,
#  64: 0.6494459,
#  65: 0.3294995,
#  66: 0.3579585,
#  67: 0.48050323,
#  68: 0.05642809,
#  69: 0.15080133,
#  70: 0.3636013,
#  71: 0.28648004,
#  72: 0.9436495,
#  73: 0.82221645,
#  74: 0.9441677,
#  75: 0.22991739,
#  76: 0.008591426,
#  77: 0.38350993,
#  78: 0.69145954,
#  79: 0.69655037,
#  80: 0.79045105,
#  81: 0.01907707,
#  82: 0.13871197,
#  83: 0.061632816,
#  84: 0.26922408,
#  85: 0.4338685,
#  86: 0.3084405,
#  87: 0.4917917,
#  88: 0.11495404,
#  89: 0.091533005,
#  90: 0.95148027,
#  91: 0.98455596,
#  92: 0.022025205,
#  93: 0.8847462,
#  94: 0.961702,
#  95: 0.73567075,
#  96: 0.8504966,
#  97: 0.73428,
#  98: 0.7234364,
#  99: 0.89727926,
#  100: 0.8208615,
#  101: 0.7158218,
#  102: 0.9108846,
#  103: 0.979255,
#  104: 0.98669577,
#  105: 0.9828225,
#  106: 0.9131707,
#  107: 0.5899665,
#  108: 0.6979175,
#  109: 0.23368438,
#  110: 0.92035544,
#  111: 0.75106895,
#  112: 0.09853983,
#  113: 0.83728147,
#  114: 0.14770693,
#  115: 0.14911117,
#  116: 0.031370677,
#  117: 0.0071774935,
#  118: 0.1049506,
#  119: 0.9753077,
#  120: 0.51932824,
#  121: 0.972138,
#  122: 0.878326,
#  123: 0.31304973,
#  124: 0.21675952,
#  125: 0.44067568,
#  126: 0.33149913,
#  127: 0.20615785,
#  128: 0.50228506,
#  129: 0.25184515,
#  130: 0.024556052,
#  131: 0.55495244,
#  132: 0.3183311,
#  133: 0.33619788,
#  134: 0.0587072,
#  135: 0.12642205,
#  136: 0.17541575,
#  137: 0.73252386,
#  138: 0.0012773193,
#  139: 0.013348013,
#  140: 0.58243924,
#  141: 0.038839594,
#  142: 0.099367686,
#  143: 0.30059192,
#  144: 0.4592124,
#  145: 0.008392262,
#  146: 0.59741175,
#  147: 0.5469863,
#  148: 0.123868346,
#  149: 0.084394194,
#  150: 0.12015847,
#  151: 0.6904546,
#  152: 0.23885569,
#  153: 0.3304357,
#  154: 0.8011274,
#  155: 0.86489105,
#  156: 0.010660429,
#  157: 0.5487057,
#  158: 0.023229392,
#  159: 0.89054567,
#  160: 0.032613896,
#  161: 0.17449175,
#  162: 0.05355162,
#  163: 0.46288493,
#  164: 0.023092905,
#  165: 0.005017361,
#  166: 0.9652924,
#  167: 0.12178637,
#  168: 0.8183973,
#  169: 0.6076201,
#  170: 0.07386997,
#  171: 0.59988457,
#  172: 0.017079096,
#  173: 0.7829352,
#  174: 0.40320125,
#  175: 0.14820518,
#  176: 0.6357808,
#  177: 0.13789262,
#  178: 0.3572636,
#  179: 0.48529032,
#  180: 0.004507278,
#  181: 0.2789212,
#  182: 0.2918514,
#  183: 0.041248694,
#  184: 0.088604055,
#  185: 0.11822523,
#  186: 0.47186148,
#  187: 0.20917527,
#  188: 0.7302011,
#  189: 0.6236929,
#  190: 0.17218204,
#  191: 0.12960945,
#  192: 0.43487623,
#  193: 0.78294116,
#  194: 0.02272994,
#  195: 0.13421232,
#  196: 0.8897362,
#  197: 0.6457043,
#  198: 0.37497306,
#  199: 0.5975284,
#  200: 0.047733508,
#  201: 0.006816916,
#  202: 0.84417987,
#  203: 0.010352697,
#  204: 0.08505471,
#  205: 0.35407904,
#  206: 0.3035773,
#  207: 0.06296587,
#  208: 0.17640302,
#  209: 0.08021467,
#  210: 0.042612202,
#  211: 0.11679618,
#  212: 0.014976363,
#  213: 0.9697249,
#  214: 0.08036591,
#  215: 0.34265214,
#  216: 0.06659493,
#  217: 0.009106204,
#  218: 0.16166724,
#  219: 0.98228973,
#  220: 0.6812678,
#  221: 0.1464377,
#  222: 0.023388796,
#  223: 0.39976797,
#  224: 0.46709678,
#  225: 0.9749561,
#  226: 0.20468466,
#  227: 0.13918726,
#  228: 0.91063577,
#  229: 0.07042742,
#  230: 0.034361005,
#  231: 0.05253431,
#  232: 0.022771848,
#  233: 0.29052848,
#  234: 0.49104705,
#  235: 0.38228303,
#  236: 0.020493962,
#  237: 0.09401109,
#  238: 0.8296775,
#  239: 0.024573997,
#  240: 0.9623717,
#  241: 0.23076496,
#  242: 0.7067875,
#  243: 0.62679136,
#  244: 0.02295804,
#  245: 0.9618307,
#  246: 0.2717559,
#  247: 0.011558525,
#  248: 0.8129256,
#  249: 0.93954474,
#  250: 0.8326524,
#  251: 0.84391856,
#  252: 0.56702,
#  253: 0.8877584,
#  254: 0.81488883,
#  255: 0.970931,
#  256: 0.85110265,
#  257: 0.39059988,
#  258: 0.8562255,
#  259: 0.5102998,
#  260: 0.4358499,
#  261: 0.84108216,
#  262: 0.25533345,
#  263: 0.43359217,
#  264: 0.048721142,
#  265: 0.017705547,
#  266: 0.09956442,
#  267: 0.91815144,
#  268: 0.95611393,
#  269: 0.21823415,
#  270: 0.16114874,
#  271: 0.63662744,
#  272: 0.29771745,
#  273: 0.06114595,
#  274: 0.9845883,
#  275: 0.041283686,
#  276: 0.13310058,
#  277: 0.33564758,
#  278: 0.31992862,
#  279: 0.029860726,
#  280: 0.26968035,
#  281: 0.016113749,
#  282: 0.7627888,
#  283: 0.08335098,
#  284: 0.73561835,
#  285: 0.0871698,
#  286: 0.080412194,
#  287: 0.6045141,
#  288: 0.15720466,
#  289: 0.33078495,
#  290: 0.023756607,
#  291: 0.6365538,
#  292: 0.7837865,
#  293: 0.75754833,
#  294: 0.044799183,
#  295: 0.9052251,
#  296: 0.9864732,
#  297: 0.5283743,
#  298: 0.33443084,
#  299: 0.07573254,
#  300: 0.00645974,
#  301: 0.637528,
#  302: 0.26201564,
#  303: 0.6240731,
#  304: 0.3810084,
#  305: 0.6031599,
#  306: 0.015282138,
#  307: 0.7785732,
#  308: 0.8001284,
#  309: 0.9773392,
#  310: 0.017274821,
#  311: 0.17710055,
#  312: 0.7643754,
#  313: 0.81393677,
#  314: 0.001905635,
#  315: 0.38358143,
#  316: 0.045705132,
#  317: 0.07410847,
#  318: 0.03169653,
#  319: 0.8178788,
#  320: 0.14245893,
#  321: 0.03266489,
#  322: 0.23588207,
#  323: 0.0014757806,
#  324: 0.44218302,
#  325: 0.043101378,
#  326: 0.44189474,
#  327: 0.3095907,
#  328: 0.15474743,
#  329: 0.31441265,
#  330: 0.025011446,
#  331: 0.4741912,
#  332: 0.025783733,
#  333: 0.063376956,
#  334: 0.82497627,
#  335: 0.17747344,
#  336: 0.016936954,
#  337: 0.7492453,
#  338: 0.97678065,
#  339: 0.35781765,
#  340: 0.17371492,
#  341: 0.09084674,
#  342: 0.39550287,
#  343: 0.14681591,
#  344: 0.66183853,
#  345: 0.018220605,
#  346: 0.0421817,
#  347: 0.001854638,
#  348: 0.07511502,
#  349: 0.008669201,
#  350: 0.012216721,
#  351: 0.8058147,
#  352: 0.019974163,
#  353: 0.3108577,
#  354: 0.86611825,
#  355: 0.7808563,
#  356: 0.21553105,
#  357: 0.3871909,
#  358: 0.06974892,
#  359: 0.1395694,
#  360: 0.0043598376,
#  361: 0.18994653,
#  362: 0.96073425,
#  363: 0.049064234,
#  364: 0.034991287,
#  365: 0.9515408,
#  366: 0.0077969353,
#  367: 0.3168618,
#  368: 0.6691731,
#  369: 0.31503087,
#  370: 0.057358794,
#  371: 0.04908915,
#  372: 0.9205396,
#  373: 0.3581629,
#  374: 0.32851905,
#  375: 0.27513024,
#  376: 0.8151239,
#  377: 0.44274125,
#  378: 0.008020082,
#  379: 0.036326613,
#  380: 0.04974816,
#  381: 0.29131788,
#  382: 0.35348073,
#  383: 0.056480236,
#  384: 0.042859696,
#  385: 0.023608426,
#  386: 0.15412508,
#  387: 0.27684423,
#  388: 0.09011385,
#  389: 0.0692781,
#  390: 0.009781072,
#  391: 0.62254775,
#  392: 0.1831956,
#  393: 0.9658657,
#  394: 0.041454162,
#  395: 0.3982523,
#  396: 0.17937158,
#  397: 0.5460842,
#  398: 0.024376858,
#  399: 0.059186827,
#  400: 0.008358335,
#  401: 0.6626471,
#  402: 0.0871089,
#  403: 0.865047,
#  404: 0.027918711,
#  405: 0.77309996,
#  406: 0.85400355,
#  407: 0.76569986,
#  408: 0.44359723,
#  409: 0.15227756,
#  410: 0.8805767,
#  411: 0.29459873,
#  412: 0.8053546,
#  413: 0.093259744,
#  414: 0.008633764,
#  415: 0.94234496,
#  416: 0.5998939,
#  417: 0.03466893,
#  418: 0.04845737,
#  419: 0.31877008}

# %% [markdown]
# #### Output Option 1 (Ideal)
#
# Semantic search results, sorted by relevance and probability of being an ad, and de-duplicated syndicated content.

# %%
for si, s in enumerate(searches):
    print(si, s)
# Out:
# 0 Long term care
# 1 General Electric
# 2 honeywell
# 3 Siemens AND AI
# 4 AI AND Healthcare
# 5 AI AND hospitals
# 6 Oracle AND AI
# 7 healthcare AND innovat
# 8 healthcare AND AI
# 9 pharma AND AI
# 10 Oracle AND data management NOT PRNewswire
# 11 healthcare AND trend
# 12 healthcare AND artificial intelligence
# 13 artificial intelligence AND healthcare
# 14 robots AND healthcare
# 15 innovation AND healthcare
# 16 telemedicine
# 17 EHR
# 18 electronic health record
# 19 longterm care
# 20 Honeywell
# 21 AI AND oncology
# 22 artificial intelligence AND oncology
# 23 oncology
# 24 pharmacy
# 25 Telemedicine
# 26 Mobile AND health
# 27 Artificial intelligence AND health
# 28 healthcare AND trend
# 29 healthcare AND artificial intelligence
# 30 artificial intelligence AND healthcare
# 31 robots AND healthcare
# 32 innovation AND healthcare
# 33 telemedicine
# 34 EHR
# 35 electronic health record
# 36 longterm care
# 37 Siemens
# 38 pharmacy AND technology
# 39 longterm care
# 40 Medtronic
# 41 Medtronic
# 42 Medtronic AND innovation
# 43 Medtronic AND innovation
# 44 Abbott Laboratories
# 45 General Electric
# 46 Abbott Laboratories
# 47 patient care AND AI
# 48 patient care AND artificial intelligence
# 49 electronic health record
# 50 electronic health records
# 51 Medtronic
# 52 EHR
# 53 clinical AND research AND innovation
# 54 Honeywell
# 55 Honeywell
# 56 Honeywell
# 57 Medtronic
# 58 Honeywell
# 59 Green Hydrogen
# 60 Green Hydrogen
# 61 NCI
# 62 NIH
# 63 National Institute of Health
# 64 oncology AND cost
# 65 Merck
# 66 cancer AND stem cells
# 67 delivery AND healthcare
# 68 personalization AND ad NOT PRNewswire
# 69 oncology
# 70 protein AND trends
# 71 Merck AND research
# 72 Merck AND development
# 73 epigenetics
# 74 cancer AND detection AND study
# 75 cancer AND detection AND research
# 76 cancer AND genomics
# 77 Illumina
# 78 Epigenomics
# 79 methylation
# 80 Merck Millipore
# 81 Merck Millipore
# 82 Millipore
# 83 Merck
# 84 10X Genomics
# 85 10X Genomics
# 86 restaurant AND sustainability
# 87 sustainability AND restaurant
# 88 BIC
# 89 gluten free AND trend
# 90 glutenfree AND trend
# 91 glutenfree
# 92 glutenfree AND trend
# 93 glutenfree AND trends
# 94 gluten free AND trend
# 95 gluten free AND trends
# 96 gas AND acquisition
# 97 gas AND merger
# 98 oil AND acquisition
# 99 oil AND merger
# 100 Solvay
# 101 FMC
# 102 FMC
# 103 Cargill
# 104 Solvay
# 105 Solvay
# 106 Green Hydrogen
# 107 Green Hydrogen
# 108 Carbon AND 3D
# 109 3D printing
# 110 fiber AND trends
# 111 Solvay
# 112 Aid AND Saudi Arabia
# 113 Human Capital Management
# 114 Solvay
# 115 Solvay
# 116 Citigroup
# 117 bank stocks
# 118 treasury secretary
# 119 monetary policy AND Fed
# 120 affordable care act
# 121 Coca Cola
# 122 Kroger
# 123 Embraer
# 124 energy policy
# 125 mortgage AND technology NOT PRNewswire NOT Business Wire NOT GLOBE NEWSWIRE NOT Marketwired NOT LifeLock Protection
# 126 Caesars Entertainment
# 127 Community Health Systems
# 128 managed care AND mental health
# 129 NVIDIA
# 130 AI AND Education
# 131 AI AND hospitals
# 132 IBM AND cloud
# 133 IBM AND services
# 134 IBM AND cybersecurity
# 135 artificial intelligence AND regulation
# 136 AI AND regulation
# 137 artificial intelligence AND congress
# 138 technology AND regulation
# 139 Cloud Computing
# 140 cybersecurity AND services
# 141 IBM AND community
# 142 Amazon AND Blink
# 143 Pfizer AND breast cancer
# 144 Pfizer AND app
# 145 Pfizer AND cancer
# 146 Pfizer AND oncology
# 147 3D Systems
# 148 Stratasys
# 149 Triumph Group
# 150 Spirit AeroSystems
# 151 Spirit Aerosystems
# 152 Apple AND enterprise
# 153 Senate AND tech companies
# 154 House AND Tech companies
# 155 Rite Aid
# 156 amazon AND pharmaceuticals
# 157 Eli Lilly
# 158 Regeneron
# 159 Virgin Galactic
# 160 pharma AND regulat
# 161 pharma AND polic
# 162 oncology
# 163 Johnson  Johnson
# 164 Eli Lilly
# 165 pharma AND innovat
# 166 pharma AND AI
# 167 Pfizer AND Spark
# 168 Pfizer AND RESET
# 169 digital AND clinical trials
# 170 hospital AND regulat
# 171 macys
# 172 app AND commerce
# 173 consumer discretionary
# 174 Regeneron
# 175 pharma AND Congress
# 176 Pfizer AND shortage
# 177 Pfizer AND protest
# 178 cybersecurity NOT PRNewswire NOT PRWeb NOT BusinessWire
# 179 cyberattack
# 180 Appian
# 181 NVIDIA AND ARTIFICIAL INTELLIGENCE
# 182 NVIDIA AND AUTOMOTIVE
# 183 The Trade Desk AND ad NOT PRNewswire
# 184 The Trade Desk AND cloud NOT PRNewswire
# 185 Affordable Care Act
# 186 health care AND regulat
# 187 health care AND consolidation
# 188 health care AND trend
# 189 health care AND digital
# 190 health care AND artificial intelligence
# 191 healthcare AND trend
# 192 healthcare AND artificial intelligence
# 193 Electric AND Vehicle
# 194 Vehicle AND Emissions
# 195 Auto AND emissions
# 196 electric AND commercial AND vehicle
# 197 electric AND Vehicle AND startup
# 198 electric AND vehicle AND battery
# 199 Technology AND Vehicle
# 200 Vehicle AND AI
# 201 5G AND car
# 202 5G AND vehicle
# 203 Union AND Auto
# 204 Regulation AND Car
# 205 Regulation AND Vehicle
# 206 Hyundai NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 207 Tesla NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 208 Highway Safety
# 209 transportation AND regulation
# 210 highway AND regulation
# 211 artificial intelligence AND healthcare
# 212 artificial intelligence AND health care
# 213 blockchain AND health care
# 214 retail AND healthcare
# 215 retail AND health care
# 216 telehealth AND healthcare
# 217 telehealth AND health care
# 218 bitcoin AND health care
# 219 innovation AND health care
# 220 health AND reform
# 221 biologics
# 222 Rite Aid
# 223 Amazon AND health
# 224 IBM AND health
# 225 One Medical
# 226 Teladoc
# 227 telehealth
# 228 consolidation AND health care
# 229 antitrust AND health care
# 230 reform AND healthcare
# 231 reform AND health care
# 232 Amazon AND healthcare
# 233 Amazon AND health care
# 234 Darden Restaurants
# 235 Dine Brands
# 236 3D Systems
# 237 Materialise AND 3D
# 238 GE AND engine
# 239 Avid AND Technology NOT PRNewswire
# 240 Brexit AND hospital
# 241 Brexit AND doctor
# 242 Brexit AND health care
# 243 Vehicle AND AI
# 244 Union AND Auto
# 245 Regulation AND Car
# 246 Regulation AND Vehicle
# 247 Eli Lilly
# 248 Johnson  Johnson
# 249 homebuilder
# 250 NVIDIA AND Cloud
# 251 Community Health Systems
# 252 biologics
# 253 Teradata
# 254 NVIDIA AND Earnings
# 255 Amazon AND tires
# 256 Pfizer AND opioid
# 257 Pfizer AND opioids
# 258 Mortgage AND regulation
# 259 GameStop
# 260 AI AND oncology
# 261 AI AND cancer
# 262 artificial intelligence AND oncology
# 263 artificial intelligence AND cancer
# 264 Artificial Intelligence AND mortgage
# 265 Amazon AND mortgage
# 266 health care AND consolidation
# 267 health care AND tech
# 268 health care AND trend
# 269 health care AND digital
# 270 health care AND artificial intelligence
# 271 health care AND virtual
# 272 health care AND data
# 273 healthcare AND trend
# 274 healthcare AND digital
# 275 healthcare AND artificial intelligence
# 276 health care AND cost
# 277 artificial intelligence AND healthcare
# 278 artificial intelligence AND health care
# 279 blockchain AND health care
# 280 retail AND healthcare
# 281 retail AND health care
# 282 telehealth AND healthcare
# 283 telehealth AND health care
# 284 virtual AND health care
# 285 bitcoin AND health care
# 286 innovation AND health care
# 287 biologics
# 288 data AND health care
# 289 telehealth
# 290 consolidation AND health care
# 291 Amazon AND healthcare
# 292 Amazon AND health care
# 293 Affordable Care Act
# 294 health care AND regulat
# 295 healthcare AND regulat
# 296 health AND reform
# 297 antitrust AND health care
# 298 reform AND healthcare
# 299 reform AND health care
# 300 Connected AND Vehicle
# 301 managed care
# 302 PBM
# 303 trade war
# 304 Pfizer AND technology
# 305 gaming AND trend
# 306 gaming AND cloud
# 307 Carpenter AND 3D
# 308 ExOne
# 309 Affordable Care Act
# 310 Telehealth
# 311 Prime Therapeutics
# 312 Kroger AND foods
# 313 US Foods
# 314 pfizer AND earnings
# 315 pfizer AND ai
# 316 pfizer AND artificial intelligence
# 317 Square AND commerce
# 318 cybersecurity AND finance
# 319 cybersecurity AND credit
# 320 Square AND commerce
# 321 Digital AND Pharmaceutical
# 322 Artificial intelligence AND health
# 323 Artificial intelligence AND pharmaceutical
# 324 Cybersecurity AND health
# 325 Johnson  Johnson AND ai
# 326 Merck AND artificial intelligence
# 327 Johnson  Johnson AND artificial intelligence
# 328 clinical trials AND digital
# 329 clinical trials AND technology
# 330 helium
# 331 gas AND acquisition
# 332 gas AND buyout
# 333 oil AND acquisition
# 334 oil AND buyout
# 335 oil AND merger
# 336 AI AND sentiment
# 337 ypf
# 338 cybersecurity AND bank
# 339 Prime Therapeutics
# 340 health care AND consolidation
# 341 health care AND trend
# 342 health care AND digital
# 343 health care AND artificial intelligence
# 344 healthcare AND artificial intelligence
# 345 artificial intelligence AND healthcare
# 346 artificial intelligence AND health care
# 347 retail AND healthcare
# 348 retail AND health care
# 349 telehealth AND healthcare
# 350 telehealth AND health care
# 351 innovation AND health care
# 352 biologics
# 353 telehealth
# 354 consolidation AND health care
# 355 Amazon AND healthcare
# 356 Amazon AND health care
# 357 Affordable Care Act
# 358 health care AND regulat
# 359 antitrust AND health care
# 360 reform AND healthcare
# 361 reform AND health care
# 362 CAE
# 363 Apple AND AI
# 364 Tesla AND AI
# 365 Rite Aid
# 366 Community Health Systems
# 367 Affordable Care Act
# 368 health care AND regulation
# 369 Biden AND healthcare
# 370 White House AND healthcare
# 371 antitrust AND health care
# 372 reform AND healthcare
# 373 reform AND health care
# 374 Teladoc
# 375 telehealth
# 376 AstraZeneca AND research
# 377 AstraZeneca AND develop
# 378 AstraZeneca AND development
# 379 AstraZeneca AND breakthrough
# 380 Eli Lilly AND research
# 381 Eli Lilly AND develop
# 382 Eli Lilly AND development
# 383 Eli Lilly AND breakthrough
# 384 Lilly AND research
# 385 Lilly AND develop
# 386 Lilly AND development
# 387 Lilly AND breakthrough
# 388 Regeneron AND research
# 389 Regeneron AND develop
# 390 Regeneron AND development
# 391 Regeneron AND breakthrough
# 392 Pfizer AND clinical trials
# 393 Pfizer AND artificial intelligence
# 394 Pfizer AND AI
# 395 Pfizer AND research
# 396 Pfizer AND develop
# 397 Pfizer AND development
# 398 colorectal cancer
# 399 medical device AND tax
# 400 Blackstone Group
# 401 Senate AND cybersecurity
# 402 United Microelectronics
# 403 electric vehicle
# 404 Lyft
# 405 hybrid cars
# 406 automo AND regulat
# 407 automo AND policy
# 408 vehicle AND regulat
# 409 vehicle AND lawsuit
# 410 vehicle AND emission
# 411 automot AND worker
# 412 automot AND employ
# 413 automo AND trade
# 414 vehicle AND policy
# 415 vehicle AND policies
# 416 Bed Bath  Beyond
# 417 cybersecurity AND satellite
# 418 Amazon AND cloud computing
# 419 pfizer AND valuation
# 420 Federal Reserve AND regulation
# 421 EV AND auto
# 422 FinTech AND Health
# 423 NVIDIA AND earnings NOT xanadu
# 424 NVIDIA AND stock
# 425 apartment AND organization
# 426 Home Depot
# 427 Amazon AND house AND design
# 428 Amazon AND apartment AND design
# 429 Amazon AND house AND organization
# 430 Amazon AND apartment AND organization
# 431 Amazon AND apartment
# 432 Eli AND Lilly AND Digital
# 433 Amazon AND Health
# 434 IBM AND Health
# 435 gaming AND policy
# 436 gaming AND regulation
# 437 AES AND energy
# 438 AES AND power NOT encryption
# 439 energy AND Argentina
# 440 energy AND Brasil
# 441 energy AND Mexico
# 442 energy AND Puerto Rico
# 443 energy AND United Kingdom
# 444 energy AND India
# 445 energy sector AND India
# 446 renewable energy AND United AND Kingdom
# 447 renewable energy AND India
# 448 Pfizer AND access
# 449 Tata AND Coronavirus
# 450 Tata AND COVID19
# 451 Merck AND access
# 452 Johnson  Johnson AND access
# 453 AstraZeneca AND access
# 454 GE AND Healthcare AND coronavirus
# 455 GE AND Healthcare AND COVID19
# 456 companies AND coronavirus
# 457 firm AND coronavirus
# 458 Jaguar NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 459 MedTech AND coronavirus
# 460 MedTech AND COVID19
# 461 uber
# 462 Lyft
# 463 Rivian
# 464 electric vehicle
# 465 electric AND auto
# 466 EV AND Vehicle
# 467 AES AND energy NOT Encryption
# 468 Nuts AND gam
# 469 health AND 5G
# 470 health AND deep AND learning
# 471 cancer AND AI
# 472 cancer AND CHIP
# 473 Veracyte
# 474 United AND Auto NOT police NOT highway NOT patrol NOT crime NOT stolen NOT drunk
# 475 United AND Auto AND Workers NOT police NOT highway NOT patrol NOT crime NOT stolen NOT drunk
# 476 Elon AND Musk AND auto
# 477 Elon AND Musk AND vehicle
# 478 Hyundai AND auto
# 479 Hyundai AND vehicle
# 480 Jaguar AND auto
# 481 Jaguar AND vehicle
# 482 NIO AND auto
# 483 NIO AND vehicle
# 484 Rivian AND auto
# 485 Rivian AND vehicle
# 486 Tesla AND auto
# 487 Tesla AND vehicle
# 488 Connected AND Vehicle AND technology
# 489 Electric AND auto
# 490 EV AND auto
# 491 EV AND vehicle
# 492 Trade AND Canada AND auto NOT police NOT highway NOT patrol NOT crime NOT stolen NOT drunk
# 493 Trade AND China AND auto NOT police NOT highway NOT patrol NOT crime NOT stolen NOT drunk
# 494 biotechnology AND health
# 495 cloud computing
# 496 business travel
# 497 drones AND regulation
# 498 drones AND export
# 499 vaccine AND distribution
# 500 Pfizer AND BioNTech AND COVID19
# 501 Pfizer AND BioNTech AND coronavirus
# 502 Pregnancy AND vaccine
# 503 Novavax AND vaccine
# 504 Novavax AND treatment
# 505 Novavax AND study
# 506 Novavax AND trial
# 507 Moderna AND treatment
# 508 Moderna AND trial
# 509 AstraZeneca AND treatment
# 510 AstraZeneca AND study
# 511 AstraZeneca AND trial
# 512 Transocean
# 513 Oceaneering
# 514 Occidental AND oil
# 515 Marathon Oil
# 516 oilfield
# 517 cruise AND damag
# 518 cruise AND threat
# 519 cruise AND medical
# 520 Disney AND cruise
# 521 special purpose acquisition company
# 522 cruise line AND coronavirus
# 523 cruise line AND COVID19
# 524 cruise line AND lockdown
# 525 cruise line AND regulat
# 526 Sally Beauty
# 527 beauty AND regulation
# 528 retail AND environmental
# 529 Eli Lilly
# 530 health care AND AI
# 531 health care AND artificial intelligence
# 532 health AND diagnostic AND AI
# 533 health AND diagnostic AND artificial intelligence
# 534 telehealth
# 535 health AND predict AND artificial intelligence
# 536 public health AND artificial intelligence
# 537 accounting AND performance
# 538 airline AND United Kingdom
# 539 airlines AND United Kingdom
# 540 airport AND United Kingdom
# 541 airports AND United Kingdom
# 542 retail AND airport
# 543 retail AND airports
# 544 finance AND airports
# 545 businesses AND airports
# 546 Solar AND reserve
# 547 Redfin
# 548 Tripadvisor
# 549 Rare AND disease AND Black
# 550 clinical AND research AND digital
# 551 clinical AND research AND disruptive
# 552 clinical AND research AND innovation
# 553 clinical AND research AND social AND media
# 554 clinical AND research AND virtual
# 555 clinical AND trial AND African AND American
# 556 clinical AND trial AND digital
# 557 clinical AND trial AND disruptive
# 558 clinical AND trial AND innovation
# 559 clinical AND trial AND social AND media
# 560 clinical AND trial AND virtual
# 561 digital AND clinical AND trials
# 562 Eidos
# 563 intellia
# 564 intellia AND CRISPR
# 565 Prothena
# 566 Valero AND retail
# 567 Valero
# 568 Aclaris
# 569 Aurora Cannabis
# 570 cannabis AND health
# 571 cannabis AND policy
# 572 cannabis AND law
# 573 cannabis AND Medical
# 574 johnson  johnson AND vaccine
# 575 Cardtronics
# 576 Pfizer AND Myovant
# 577 Kohls
# 578 Regeneron
# 579 European AND Commission AND Social AND Policy
# 580 IBM AND cloud
# 581 IBM AND cybersecurity
# 582 IBM AND community
# 583 artificial intelligence AND regulation
# 584 AI AND regulation
# 585 Editas Medicine
# 586 Vehicle AND regulation
# 587 Embraer
# 588 monetary policy
# 589 bank AND regulation
# 590 bank AND regulation
# 591 monetary policy
# 592 entertainment AND subscription
# 593 Apple AND medicine
# 594 Apple AND pharma
# 595 Apple AND doctor
# 596 Amazon AND medicine
# 597 Amazon AND pharma
# 598 Amazon AND medical
# 599 Amazon AND doctor
# 600 Microsoft AND drug
# 601 Microsoft AND medical
# 602 Microsoft AND doctor
# 603 Teladoc
# 604 mortgage rates
# 605 renewable energy AND mining NOT bitcoin mining NOT mining bitcoin NOT crypto mining NOT mining crypto NOT cryptocurrency mining NOT mining cryptocurrencies
# 606 Joe Biden AND covid AND therapy
# 607 Joe Biden AND covid AND treatment
# 608 Kamala Harris AND covid AND treatment
# 609 Anthony Fauci AND covid AND treatment
# 610 Lloyd Austin AND covid AND treatment
# 611 IBM AND health
# 612 IBM AND pharma
# 613 IBM AND medical
# 614 IBM AND doctor
# 615 Johnson  Johnson
# 616 Xpel
# 617 johnson  johnson AND infectious disease
# 618 Amazon AND cloud
# 619 Artificial Intelligence AND pharma
# 620 Embraer
# 621 infrastructure AND regulation
# 622 Signet Jewelers
# 623 Fitch AND hold
# 624 Fitch AND rates
# 625 Fitch AND hold
# 626 Fitch AND rates
# 627 Fitch AND upgrade
# 628 Fitch AND downgrade
# 629 Fitch AND upgrade
# 630 Fitch AND downgrade
# 631 Indian AND Dark Horse
# 632 pharma AND prices
# 633 pharmaceutical AND prices
# 634 pharmaceuticals AND environment
# 635 pharmaceuticals AND emissions
# 636 pharmaceuticals AND justice
# 637 pharmaceuticals AND false claims
# 638 pharmaceuticals AND prices
# 639 Johnson  Johnson AND environment
# 640 Johnson  Johnson AND emissions
# 641 Johnson  Johnson AND justice
# 642 Johnson  Johnson AND false claims
# 643 Johnson  Johnson AND prices
# 644 Merck AND prices
# 645 Pfizer AND environment
# 646 Pfizer AND emissions
# 647 Pfizer AND false claims
# 648 Pfizer AND prices
# 649 biotechnology AND emissions
# 650 biotechnology AND environment
# 651 biotechnology AND false claims
# 652 biotechnology AND justice
# 653 biotechnology AND prices
# 654 ProcterGamble
# 655 Procter  Gamble
# 656 Johnson  Johnson
# 657 JohnsonJohnson
# 658 cloud computing
# 659 AI AND sentiment
# 660 PBF Energy
# 661 energy sector AND cybersecurity
# 662 consumer discretionary
# 663 consumer staples
# 664 Nvidia AND research
# 665 midstream
# 666 Transocean
# 667 Nabors Industries
# 668 cybersecurity AND regulation
# 669 artificial intelligence AND Pentagon
# 670 artificial intelligence AND military
# 671 artificial intelligence AND defense
# 672 Pfizer AND COVID19 AND treatment
# 673 Regeneron AND COVID19 AND treatment
# 674 Lilly AND COVID19 AND treatment
# 675 teladoc
# 676 SEC AND Senate NOT basketball NOT football NOT southeastern conference NOT NCAA NOT college NOT athletics
# 677 SEC AND House of Representatives NOT basketball NOT football NOT southeastern conference NOT NCAA NOT college NOT athletics
# 678 Clinical AND trials AND access
# 679 Clinical AND trials AND innovation
# 680 Clinical AND trials AND technology
# 681 Clinical AND trials AND digital
# 682 luxury AND eCommerce
# 683 media AND eCommerce
# 684 social media AND eCommerce
# 685 Vaccine AND hesitancy
# 686 Caterpillar AND construction
# 687 Apollo AND tires
# 688 United States AND tires
# 689 US AND tires
# 690 tires AND artificial intelligence
# 691 tires AND AI
# 692 cryptocurrency AND reform
# 693 cryptocurrency AND regulation
# 694 Disney AND cruise
# 695 Regeneron
# 696 Vehicle AND regulation
# 697 pharmaceuticals AND acquisition
# 698 Johnson  Johnson AND Covid AND vaccines
# 699 Johnson  Johnson AND Covid19 AND vaccines
# 700 Johnson  Johnson AND coronavirus AND vaccine
# 701 Johnson  Johnson AND coronavirus AND vaccines
# 702 Johnson AND Johnson AND coronavirus AND vaccine
# 703 Johnson AND Johnson AND coronavirus AND vaccines
# 704 Astrazeneca AND coronavirus AND vaccine
# 705 Astrazeneca AND coronavirus AND vaccines
# 706 regulators AND covid AND vaccines
# 707 regulators AND covid AND vaccinations
# 708 regulators AND covid19 AND vaccines
# 709 regulators AND covid19 AND vaccinations
# 710 Congress AND covid AND vaccine
# 711 Congress AND covid AND vaccines
# 712 Congress AND covid19 AND vaccine
# 713 Congress AND covid19 AND vaccines
# 714 White House AND covid AND vaccines
# 715 White House AND covid AND vaccinations
# 716 White House AND covid19 AND vaccine
# 717 White House AND covid19 AND vaccines
# 718 White House AND covid19 AND vaccinations
# 719 pharma AND coronavirus AND vaccine
# 720 pharma AND coronavirus AND vaccines
# 721 pharma AND covid AND vaccine
# 722 pharma AND covid AND vaccines
# 723 pharma AND covid19 AND vaccine
# 724 pharma AND covid19 AND vaccines
# 725 health care reform
# 726 cybersecurity AND health care
# 727 Houghton Mifflin Harcourt
# 728 pharmaceuticals AND trade
# 729 Seattle AND coronavirus
# 730 Seattle AND lockdown
# 731 Seattle AND restrict
# 732 Procter  Gamble AND ecommerce
# 733 hotel AND tech
# 734 hotel AND digital
# 735 hospitality AND tech
# 736 hospitality AND technology
# 737 hospitality AND software
# 738 hospitality AND digital
# 739 maritime AND intelligence
# 740 biotech AND valuation
# 741 biotech AND acquisition
# 742 Amazon AND regulation
# 743 cloud AND data AND policy
# 744 cloud AND data AND regulation
# 745 cloud AND data AND regulators
# 746 metaverse AND policy
# 747 metaverse AND regulation
# 748 Johnson  Johnson
# 749 biotech AND rais
# 750 biotech AND law
# 751 crypto AND cybersecurity
# 752 Eli Lilly
# 753 railroad AND rate
# 754 railroad AND acquisition
# 755 oil AND midstream
# 756 gas AND midstream
# 757 energy AND midstream
# 758 AWS
# 759 sustainability AND tech industry
# 760 Nuance AND cloud NOT PRNewswire
# 761 GM NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 762 AWS
# 763 Intel AND cloud
# 764 cyber security AND cloud
# 765 reinvent
# 766 liberty mutual
# 767 tech industry AND hiring
# 768 tech industry AND environment
# 769 tech industry AND sustainability
# 770 Nuance
# 771 AWS
# 772 systems engineering
# 773 Intel AND research
# 774 tractor AND manufacturing
# 775 Unilever
# 776 Manufacturing AND Automotive
# 777 Manufacturing AND Automotive
# 778 manufactur AND automo
# 779 automot AND employ
# 780 Unilever
# 781 Unilever
# 782 Unilever
# 783 civil aviation
# 784 Embraer
# 785 garmin
# 786 honeywell
# 787 Honeywell AND aerospace
# 788 Sikorsky
# 789 Textron Aviation
# 790 Honda NOT Mike Honda NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT Keisuke NOT arson
# 791 Airline AND Safety
# 792 aviation AND safety
# 793 faa AND safety
# 794 Federal Aviation Administration AND safety
# 795 NTSB
# 796 Honda AND government
# 797 Honda AND Pilot NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 798 Honda AND Jet
# 799 Honda AND Lincoln
# 800 Honda AND Aircraft
# 801 Honeywell
# 802 Training AND Lockheed
# 803 F22
# 804 F16 AND Lockheed
# 805 Dallas AND Lockheed
# 806 Baltimore AND Lockheed
# 807 Helicopters AND Lockheed
# 808 CH148 AND Sikorsky
# 809 CH148 Cyclone AND Sikorsky
# 810 Lockheed Martin
# 811 Lockheed
# 812 Bell Textron
# 813 Dassault
# 814 F35A
# 815 F35B
# 816 F35C
# 817 Lockheed AND military
# 818 Lockheed AND air force
# 819 AGCO NOT alcohol and gaming commission of ontario
# 820 NTSB
# 821 AGCO AND Service
# 822 Raytheon
# 823 health AND 5G
# 824 IAI AND drone
# 825 Airbus AND drone
# 826 UAS AND government
# 827 drones AND government
# 828 airlines AND UK
# 829 airlines AND United Kingdom
# 830 airport AND UK
# 831 airport AND United Kingdom
# 832 airports AND UK
# 833 business AND airport
# 834 business AND airports
# 835 FBO
# 836 FBOs
# 837 Attack AND airport
# 838 GKN
# 839 Honeywell
# 840 Raytheon
# 841 Epic AND Garmin
# 842 Epic AND Honeywell
# 843 StandardAero
# 844 MT Propeller
# 845 Experimental Aircraft Association
# 846 One Aviation
# 847 Embraer
# 848 Airbus AND Helicopter
# 849 Honeywell
# 850 Training AND Sikorsky
# 851 CH148 AND Lockheed
# 852 CH148 AND helicopter
# 853 CH148 Cyclone
# 854 Airbus
# 855 Embraer
# 856 Eurofighter
# 857 Textron
# 858 American Airlines
# 859 United Airlines
# 860 Embraer
# 861 Airbus AND helicopter
# 862 Eurofighter
# 863 Boeing AND Helicopter
# 864 Raytheon
# 865 Dassault Aviation
# 866 Lockheed Martin
# 867 Aerojet
# 868 Sikorsky
# 869 US AND Department of Transportation
# 870 FAA
# 871 Embraer
# 872 garmin
# 873 honeywell
# 874 Honeywell AND aerospace
# 875 RollsRoyce AND jet
# 876 Rolls Royce AND jet
# 877 RollsRoyce AND aerospace
# 878 Sikorsky
# 879 Textron Aviation
# 880 Honda NOT Mike Honda NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT Keisuke NOT arson
# 881 Airline AND Safety
# 882 aviation AND safety
# 883 faa AND safety
# 884 Federal Aviation Administration AND safety
# 885 NTSB
# 886 Honda AND government
# 887 Honda AND Pilot NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 888 Honda AND Jet
# 889 Honda AND Lincoln
# 890 Honda AND Aircraft
# 891 Honeywell
# 892 Training AND Lockheed
# 893 F22
# 894 F16 AND Lockheed
# 895 Dallas AND Lockheed
# 896 Baltimore AND Lockheed
# 897 Helicopters AND Lockheed
# 898 CH148 AND Sikorsky
# 899 CH148 Cyclone AND Sikorsky
# 900 Lockheed Martin
# 901 Lockheed
# 902 Bell Textron
# 903 Dassault
# 904 F35A
# 905 F35B
# 906 F35C
# 907 Lockheed AND military
# 908 Lockheed AND air force
# 909 AGCO NOT alcohol and gaming commission of ontario
# 910 NTSB
# 911 AGCO AND Service
# 912 Raytheon
# 913 RollsRoyce
# 914 health AND 5G
# 915 IAI AND drone
# 916 Airbus AND drone
# 917 UAS AND government
# 918 airlines AND UK
# 919 airlines AND United Kingdom
# 920 airport AND UK
# 921 airport AND United Kingdom
# 922 airports AND UK
# 923 business AND airport
# 924 business AND airports
# 925 FBO
# 926 FBOs
# 927 Attack AND airport
# 928 GKN
# 929 Honeywell
# 930 Raytheon
# 931 Embraer AND Honeywell
# 932 Epic AND Garmin
# 933 Epic AND Honeywell
# 934 StandardAero
# 935 MT Propeller
# 936 Experimental Aircraft Association
# 937 One Aviation
# 938 Embraer
# 939 Airbus AND Helicopter
# 940 Honeywell
# 941 Training AND Sikorsky
# 942 CH148 AND Lockheed
# 943 CH148 AND helicopter
# 944 CH148 Cyclone
# 945 Airbus
# 946 Embraer
# 947 Eurofighter
# 948 Textron
# 949 American Airlines
# 950 United Airlines
# 951 Embraer
# 952 Airbus AND helicopter
# 953 Eurofighter
# 954 RollsRoyce AND aviation
# 955 RollsRoyce AND aerospace
# 956 RollsRoyce AND aircraft
# 957 Boeing AND Helicopter
# 958 Raytheon
# 959 RollsRoyce AND aviation
# 960 RollsRoyce AND aerospace
# 961 RollsRoyce AND aircraft
# 962 Rolls AND Royce AND aviation
# 963 Rolls AND Royce AND aerospace
# 964 Rolls AND Royce AND aircraft
# 965 Dassault Aviation
# 966 Lockheed Martin
# 967 Aerojet
# 968 Sikorsky
# 969 US AND Department of Transportation
# 970 FAA
# 971 Tim Hortons
# 972 ExxonMobil
# 973 BASF
# 974 agronomy AND agriculture
# 975 Moon AND 2024
# 976 Registered Nurses
# 977 employment AND trends
# 978 Bayer NOT Leverkusen NOT aflak
# 979 ExxonMobil
# 980 Exxon
# 981 First Nations AND Energy
# 982 First Nations AND Resources
# 983 indigenous AND Energy
# 984 indigenous AND Energy
# 985 indigenous AND Resources
# 986 Canada Pension Plan
# 987 Canada Pension Plan Investment Board
# 988 Cargill
# 989 statistics canada
# 990 canada AND statistics
# 991 Canada AND employment
# 992 Canada AND employment
# 993 Canada AND pension plan
# 994 Canadian pension plan
# 995 women AND advisors
# 996 computer engineering
# 997 AI AND conference
# 998 Brexit AND hospital
# 999 Pall
# 1000 Square AND small business
# 1001 Jordan AND Cove
# 1002 Jordan AND Cove
# 1003 3M
# 1004 3M
# 1005 3M
# 1006 3M
# 1007 United AND flight
# 1008 Fuchs
# 1009 3M NOT 3M ago
# 1010 3M NOT 3M ago
# 1011 3M NOT 3M ago
# 1012 Ryan AND Austin
# 1013 3M NOT 3M Ago
# 1014 3M NOT 3M Ago
# 1015 3M NOT 3M Ago
# 1016 Directed Energy
# 1017 tax AND tech
# 1018 Tencent
# 1019 Chipotle
# 1020 biologics
# 1021 Chipotle
# 1022 China AND sanctions
# 1023 PetroChina
# 1024 oil prices
# 1025 business AND airport
# 1026 Dupont
# 1027 Boeing
# 1028 Centers for Disease Control
# 1029 Food and Drug Administration
# 1030 FDA
# 1031 Centers for disease control and prevention
# 1032 Pfizer
# 1033 Johnson  Johnson NOT Captioning made possible by Johnson  Johnson
# 1034 Centers for Disease Control and Prevention
# 1035 CDC
# 1036 FDA
# 1037 Food and Drug Administration
# 1038 Rochelle Walensky
# 1039 Rochelle Walensky
# 1040 Janet Woodcock
# 1041 Janet Woodcock
# 1042 Pfizer AND vaccin
# 1043 Pfizer
# 1044 Johnson  Johnson
# 1045 Pfizer
# 1046 FDA
# 1047 Pfizer
# 1048 COVID19
# 1049 Pfizer AND access
# 1050 Pfizer AND access
# 1051 Johnson  Johnson AND access
# 1052 Johnson  Johnson AND access
# 1053 Johnson  Johnson
# 1054 Johnson  Johnson
# 1055 Pfizer
# 1056 Pfizer
# 1057 Pfizer AND BioNTech AND COVID19
# 1058 Rochelle Walensky
# 1059 Rochelle Walensky
# 1060 COVID
# 1061 COVID
# 1062 BioNTech AND covid
# 1063 BioNTech AND covid
# 1064 Pfizer AND covid
# 1065 Pfizer AND covid
# 1066 Covid19
# 1067 Covid19
# 1068 Janet Woodcock
# 1069 Janet Woodcock
# 1070 Johnson  Johnson
# 1071 Johnson  Johnson
# 1072 Pfizer
# 1073 Pfizer
# 1074 Food and Drug Administration
# 1075 Food and Drug Administration
# 1076 Janet Woodcock
# 1077 Janet Woodcock
# 1078 Johnson  Johnson
# 1079 Johnson  Johnson
# 1080 vaccines AND mRNA
# 1081 Pfizer
# 1082 fda AND authorization
# 1083 fda AND authorization
# 1084 Janet Woodcock
# 1085 Janet Woodcock
# 1086 Pfizer AND covid AND vaccine
# 1087 Pfizer AND covid AND vaccine
# 1088 Pfizer AND covid AND booster
# 1089 Pfizer AND covid AND booster
# 1090 Pfizer AND covid AND shots
# 1091 Pfizer AND covid AND shots
# 1092 Pfizer AND BioNTech AND covid AND vaccine
# 1093 Pfizer AND BioNTech AND covid AND vaccine
# 1094 Pfizer AND BioNTech AND covid AND booster
# 1095 Pfizer AND BioNTech AND covid AND booster
# 1096 Pfizer AND BioNTech AND covid AND shots
# 1097 Pfizer AND BioNTech AND covid AND shots
# 1098 PfizerBioNTech AND covid AND booster
# 1099 PfizerBioNTech AND covid AND booster
# 1100 PfizerBioNTech AND covid AND shots
# 1101 PfizerBioNTech AND covid AND shots
# 1102 PfizerBioNTech AND covid19 AND shots
# 1103 PfizerBioNTech AND covid19 AND shots
# 1104 Johnson  Johnson AND Covid AND vaccine
# 1105 Johnson  Johnson AND Covid AND vaccine
# 1106 Johnson  Johnson AND Covid AND vaccines
# 1107 Johnson  Johnson AND Covid AND vaccines
# 1108 Johnson  Johnson AND Covid19 AND vaccine
# 1109 Johnson  Johnson AND Covid19 AND vaccine
# 1110 Johnson  Johnson AND Covid19 AND vaccines
# 1111 Johnson  Johnson AND Covid19 AND vaccines
# 1112 Johnson  Johnson AND Covid AND booster
# 1113 Johnson  Johnson AND Covid AND booster
# 1114 Johnson  Johnson AND Covid19 AND booster
# 1115 Johnson  Johnson AND Covid19 AND booster
# 1116 Johnson AND Johnson AND Covid AND vaccine
# 1117 Johnson AND Johnson AND Covid AND vaccine
# 1118 Johnson AND Johnson AND Covid AND vaccines
# 1119 Johnson AND Johnson AND Covid AND vaccines
# 1120 Johnson AND Johnson AND Covid19 AND vaccine
# 1121 Johnson AND Johnson AND Covid19 AND vaccine
# 1122 Johnson AND Johnson AND Covid19 AND vaccines
# 1123 Johnson AND Johnson AND Covid19 AND vaccines
# 1124 Johnson AND Johnson AND Covid AND booster
# 1125 Johnson AND Johnson AND Covid AND booster
# 1126 Johnson AND Johnson AND Covid19 AND booster
# 1127 Johnson AND Johnson AND Covid19 AND booster
# 1128 Moderna AND Covid AND vaccine
# 1129 Moderna AND Covid AND vaccine
# 1130 Moderna AND Covid AND vaccines
# 1131 Moderna AND Covid AND vaccines
# 1132 Moderna AND Covid19 AND vaccine
# 1133 Moderna AND Covid19 AND vaccine
# 1134 Moderna AND Covid19 AND vaccines
# 1135 Moderna AND Covid19 AND vaccines
# 1136 Moderna AND Covid AND booster
# 1137 Moderna AND Covid AND booster
# 1138 Moderna AND Covid19 AND booster
# 1139 Moderna AND Covid19 AND booster
# 1140 Pfizer AND covid AND vaccines
# 1141 Pfizer AND covid AND vaccines
# 1142 FDA AND covid AND vaccine
# 1143 FDA AND covid AND vaccine
# 1144 FDA AND covid AND vaccines
# 1145 FDA AND covid AND vaccines
# 1146 FDA AND covid19 AND vaccine
# 1147 FDA AND covid19 AND vaccine
# 1148 FDA AND covid19 AND vaccines
# 1149 FDA AND covid19 AND vaccines
# 1150 Food and Drug Administration AND covid AND vaccine
# 1151 Food and Drug Administration AND covid AND vaccine
# 1152 Food and Drug Administration AND covid AND vaccines
# 1153 Food and Drug Administration AND covid AND vaccines
# 1154 Food and Drug Administration AND covid19 AND vaccine
# 1155 Food and Drug Administration AND covid19 AND vaccine
# 1156 Food and Drug Administration AND covid19 AND vaccines
# 1157 Food and Drug Administration AND covid19 AND vaccines
# 1158 CDC AND covid AND vaccine
# 1159 CDC AND covid AND vaccine
# 1160 CDC AND covid AND vaccines
# 1161 CDC AND covid AND vaccines
# 1162 CDC AND covid19 AND vaccine
# 1163 CDC AND covid19 AND vaccine
# 1164 CDC AND covid19 AND vaccines
# 1165 CDC AND covid19 AND vaccines
# 1166 WHO AND covid AND vaccine
# 1167 WHO AND covid AND vaccine
# 1168 WHO AND covid AND vaccines
# 1169 WHO AND covid AND vaccines
# 1170 WHO AND covid19 AND vaccine
# 1171 WHO AND covid19 AND vaccine
# 1172 WHO AND covid19 AND vaccines
# 1173 WHO AND covid19 AND vaccines
# 1174 Pfizer AND BioNTech AND covid AND vaccines
# 1175 Pfizer AND BioNTech AND covid AND vaccines
# 1176 Pfizer AND BioNTech AND covid19 AND vaccines
# 1177 Pfizer AND BioNTech AND covid19 AND vaccines
# 1178 pfizer AND covid19 AND vaccine
# 1179 pfizer AND covid19 AND vaccine
# 1180 pfizer AND covid19 AND booster
# 1181 pfizer AND covid19 AND booster
# 1182 Kite NOT Kite mark NOT kite surf NOT kitesurf NOT Harry Kite NOT Kite Factory NOT Kite Trust NOT Kite Consulting NOT fly a kite NOT Kite Packaging NOT kitefly NOT kitemak NOT kites tale NOT Red Kite NOT Sheffield Kite Flyers NOT flying a kite NOT high as a kite NOT Kite Festival NOT Kite Beach NOT Kite Street NOT Kite Realty
# 1183 ACE AND medical NOT Ace Hardware NOT ACE inhibitors NOT Ace wood flooring
# 1184 Boots AND COVID19 NOT ankle boots NOT cowboy boots NOT welly boots NOT hiking NOT fill your boots NOT rain boots NOT combat boots NOT heeled boots NOT leather boots NOT chunky boots NOT boots on the ground NOT black boots NOT riding boots NOT work boots NOT thighhigh NOT fur boots NOT football boots NOT suede boots NOT hanging the boots
# 1185 Boots AND covid NOT ankle boots NOT cowboy boots NOT welly boots NOT hiking NOT fill your boots NOT rain boots NOT combat boots NOT heeled boots NOT leather boots NOT chunky boots NOT boots on the ground NOT black boots NOT riding boots NOT work boots NOT thighhigh NOT fur boots NOT football boots NOT suede boots NOT hanging the boots
# 1186 Boots AND coronavirus NOT ankle boots NOT cowboy boots NOT welly boots NOT hiking NOT fill your boots NOT rain boots NOT combat boots NOT heeled boots NOT leather boots NOT chunky boots NOT boots on the ground NOT black boots NOT riding boots NOT work boots NOT thighhigh NOT fur boots NOT football boots NOT suede boots NOT hanging the boots
# 1187 Boots AND pandemic NOT ankle boots NOT cowboy boots NOT welly boots NOT hiking NOT fill your boots NOT rain boots NOT combat boots NOT heeled boots NOT leather boots NOT chunky boots NOT boots on the ground NOT black boots NOT riding boots NOT work boots NOT thighhigh NOT fur boots NOT football boots NOT suede boots NOT hanging the boots
# 1188 Philip Morris
# 1189 Nestle NOT nestled
# 1190 Unilever
# 1191 Continental AND self AND driving
# 1192 Simulation AND self AND driving
# 1193 Conagra
# 1194 Nestle
# 1195 GMO
# 1196 food AND Natural
# 1197 foods AND Natural
# 1198 canola AND farmer
# 1199 canola AND harvest
# 1200 canola AND imports
# 1201 canola AND market
# 1202 canola AND price
# 1203 canola AND prices
# 1204 soybean AND export
# 1205 soybean AND farmer
# 1206 soybean AND harvest
# 1207 soybean AND market
# 1208 soybean AND price
# 1209 wheat AND farmer
# 1210 wheat AND harvest
# 1211 wheat AND imports
# 1212 wheat AND market
# 1213 wheat AND price
# 1214 wheat AND prices
# 1215 Bill Gates AND health
# 1216 health AND 5G
# 1217 health AND predictions AND AI
# 1218 Cargill
# 1219 airlines AND UK
# 1220 flyers AND UK
# 1221 Unilever
# 1222 dairy AND farmer
# 1223 dairy AND harvest
# 1224 dairy AND imports
# 1225 Unilever
# 1226 Sams Club
# 1227 Pfizer AND app
# 1228 Herd immunity AND vaccine
# 1229 immunization
# 1230 vaccine
# 1231 Johnson  Johnson
# 1232 health care AND digital
# 1233 Amazon AND health
# 1234 Amazon AND health care
# 1235 health insurance
# 1236 health care AND digital
# 1237 Amazon AND health care
# 1238 Meijer
# 1239 Meijer
# 1240 Sams Club
# 1241 Amazon AND health care
# 1242 AstraZeneca AND researchers
# 1243 Pfizer AND researchers
# 1244 Johnson  Johnson
# 1245 FDA AND coronavirus
# 1246 Amazon AND Health
# 1247 pregnant AND vaccine
# 1248 pregnant AND immunization
# 1249 Novavax AND vaccine
# 1250 Pfizer AND covid
# 1251 Apple AND physician
# 1252 Apple AND patient
# 1253 Amazon AND medical
# 1254 Amazon AND hospital
# 1255 Amazon AND physician
# 1256 Amazon AND patient
# 1257 Mayo Clinic
# 1258 Johnson  Johnson
# 1259 Pfizer AND coronavirus AND vaccine
# 1260 Pfizer AND coronavirus AND booster
# 1261 Johnson  Johnson AND Covid AND vaccine
# 1262 Johnson  Johnson AND Covid AND vaccines
# 1263 Johnson  Johnson AND Covid19 AND vaccine
# 1264 Johnson  Johnson AND Covid19 AND vaccines
# 1265 Johnson  Johnson AND coronavirus AND vaccine
# 1266 Johnson  Johnson AND coronavirus AND vaccines
# 1267 Johnson  Johnson AND Covid AND booster
# 1268 Johnson  Johnson AND Covid19 AND booster
# 1269 Johnson  Johnson AND coronavirus AND booster
# 1270 Johnson AND Johnson AND Covid AND vaccine
# 1271 Johnson AND Johnson AND Covid AND vaccines
# 1272 Johnson AND Johnson AND Covid19 AND vaccine
# 1273 Johnson AND Johnson AND Covid19 AND vaccines
# 1274 Johnson AND Johnson AND coronavirus AND vaccine
# 1275 Johnson AND Johnson AND coronavirus AND vaccines
# 1276 Johnson AND Johnson AND Covid AND booster
# 1277 Johnson AND Johnson AND Covid19 AND booster
# 1278 Johnson AND Johnson AND coronavirus AND booster
# 1279 Moderna AND Covid AND vaccine
# 1280 Moderna AND Covid19 AND vaccine
# 1281 Moderna AND Covid19 AND vaccines
# 1282 Moderna AND coronavirus AND vaccine
# 1283 Moderna AND coronavirus AND vaccines
# 1284 Moderna AND Covid19 AND booster
# 1285 Moderna AND coronavirus AND booster
# 1286 Astrazeneca AND Covid AND vaccine
# 1287 Astrazeneca AND Covid AND vaccines
# 1288 Astrazeneca AND Covid19 AND vaccine
# 1289 Astrazeneca AND Covid19 AND vaccines
# 1290 Astrazeneca AND coronavirus AND vaccine
# 1291 Astrazeneca AND coronavirus AND vaccines
# 1292 Astrazeneca AND Covid AND booster
# 1293 Astrazeneca AND Covid19 AND booster
# 1294 Astrazeneca AND coronavirus AND booster
# 1295 FDA AND covid AND vaccine
# 1296 FDA AND covid AND vaccinations
# 1297 FDA AND covid19 AND vaccine
# 1298 FDA AND covid19 AND vaccines
# 1299 FDA AND covid19 AND vaccinations
# 1300 Biden AND covid AND vaccine
# 1301 Biden AND covid AND vaccines
# 1302 Biden AND covid19 AND vaccine
# 1303 Biden AND covid19 AND vaccines
# 1304 CDC AND coronavirus AND vaccine
# 1305 CDC AND coronavirus AND vaccines
# 1306 CDC AND coronavirus AND vaccinations
# 1307 CDC AND covid AND vaccine
# 1308 CDC AND covid AND vaccinations
# 1309 CDC AND covid19 AND vaccine
# 1310 CDC AND covid19 AND vaccinations
# 1311 Johnson  Johnson
# 1312 Moderna
# 1313 carbon AND capture
# 1314 Internet of things
# 1315 United AND aircraft
# 1316 Pioneer AND oil
# 1317 refiner AND gas
# 1318 aircraft AND environment
# 1319 aircraft AND safet
# 1320 thermal imaging
# 1321 digital AND shop
# 1322 sustainability AND technology
# 1323 European Space Agency
# 1324 Congress AND technology
# 1325 healthcare AND digital
# 1326 healthcare AND data
# 1327 healthcare AND cost
# 1328 Quest AND Diagnostics
# 1329 analytics AND healthcare
# 1330 data AND healthcare
# 1331 CMS
# 1332 Renishaw
# 1333 3D printing
# 1334 UK AND Healthcare
# 1335 Honeywell
# 1336 Parker Hannifin
# 1337 CMS
# 1338 IoT AND study
# 1339 healthcare AND tech
# 1340 healthcare AND digital
# 1341 healthcare AND data
# 1342 healthcare AND cost
# 1343 analytics AND healthcare
# 1344 data AND healthcare
# 1345 CMS
# 1346 Digital AND Pharmaceutical
# 1347 Analytics AND pharmaceutical
# 1348 gas AND environment
# 1349 oil AND emissions
# 1350 oil AND environment
# 1351 emissions
# 1352 gas AND UK
# 1353 gas AND United Kingdom
# 1354 power AND United Kingdom
# 1355 energy AND UK
# 1356 energy AND United Kingdom
# 1357 CMS
# 1358 pharmaceutical AND supply chain
# 1359 pharmaceutical AND analytics
# 1360 Total AND petrochemical
# 1361 Total AND refiner
# 1362 Analog Devices
# 1363 Sustainability AND business
# 1364 Sustainability AND corporate
# 1365 energy AND Mexico
# 1366 energy AND United Kingdom
# 1367 battery AND Energy
# 1368 Smart Cities
# 1369 Honeywell
# 1370 COVID AND diagnostics
# 1371 ABB
# 1372 Honeywell
# 1373 Parker Hannifin
# 1374 Ariane 5
# 1375 electronic engineering
# 1376 AI AND study
# 1377 neural networks
# 1378 robots
# 1379 sustainability AND data
# 1380 Electric vehicle
# 1381 EV
# 1382 supply chain AND manufacturers
# 1383 Industrial AND IOT
# 1384 automation AND upskill
# 1385 airline
# 1386 airlines
# 1387 pilot
# 1388 Unilever
# 1389 Unilever
# 1390 airlines AND legislation
# 1391 United AND airline
# 1392 United AND airlines
# 1393 health AND legislat
# 1394 airline AND British
# 1395 airline AND British
# 1396 airlines AND British
# 1397 airlines AND British
# 1398 Unilever
# 1399 Unilever
# 1400 Unilever
# 1401 autonomous AND vehicle
# 1402 autonomous AND vehicles
# 1403 autonomous AND driving
# 1404 sustainability AND technology
# 1405 Plastic waste
# 1406 Autonomous AND Vehicle
# 1407 Hybrid AND Vehicle
# 1408 Shell AND UK
# 1409 Shell AND UK
# 1410 global warming
# 1411 Saint Gobain
# 1412 WSP
# 1413 Autonomous AND vehicles
# 1414 Autonomous AND vehicles
# 1415 retail AND carbon neutral
# 1416 retail AND single use plastics
# 1417 Saint Gobain
# 1418 Panasonic
# 1419 circularity
# 1420 Paris agreement
# 1421 SaintGobain
# 1422 autonomous vehicles
# 1423 energy management
# 1424 Electric vehicle
# 1425 charging
# 1426 Cloud AND funding
# 1427 climate AND risk AND housing
# 1428 Boost AND retail
# 1429 environment AND retail
# 1430 environmental AND retail
# 1431 DEA AND special agent
# 1432 Venmo
# 1433 Emerson
# 1434 Emerson
# 1435 honeywell
# 1436 Tata Consultancy
# 1437 Accenture
# 1438 HCL
# 1439 Infosys
# 1440 tech AND visa
# 1441 Wipro
# 1442 CA Technologies
# 1443 Microsoft AND cloud
# 1444 Honeywell
# 1445 Wipro
# 1446 Accenture
# 1447 Deloitte
# 1448 Infosys
# 1449 Tata AND Consultancy AND Services
# 1450 Wipro
# 1451 education AND equity
# 1452 private equity AND bill
# 1453 private equity AND policy
# 1454 CA Technologies
# 1455 energy AND India
# 1456 SMEC
# 1457 accounting AND compliance
# 1458 finance AND airports
# 1459 financial AND airports
# 1460 business AND airports
# 1461 Honeywell
# 1462 SSI AND senior
# 1463 Deloitte
# 1464 Honeywell
# 1465 Accenture NOT Let there be change Accenture
# 1466 Estate AND Planning AND Will
# 1467 Amazon AND cloud
# 1468 Google AND cloud
# 1469 Accenture AND outsourcing
# 1470 Accenture AND IT services
# 1471 Infosys AND outsourcing
# 1472 Infosys AND IT services
# 1473 ARM AND TCS
# 1474 Microsoft AND TCS
# 1475 Wipro AND outsourcing
# 1476 Wipro AND IT services
# 1477 cloud computing
# 1478 information systems
# 1479 Accenture
# 1480 Deloitte AND IT
# 1481 Infosys
# 1482 HCL
# 1483 Tata Consultancy
# 1484 Wipro
# 1485 TCS
# 1486 IT Services
# 1487 Samsung AND Note
# 1488 ACE AND medical NOT Ace Hardware NOT ACE inhibitors NOT Ace wood flooring
# 1489 curved AND touchscreen
# 1490 Camera AND smartphone
# 1491 Marriott
# 1492 accor
# 1493 ihg
# 1494 hyatt
# 1495 travel AND executive
# 1496 travel AND merger
# 1497 hotel AND executive
# 1498 hotel AND merger
# 1499 tourism AND merger
# 1500 SAAB NOT Elie Saab
# 1501 Kongsberg
# 1502 Embraer
# 1503 American AND flight
# 1504 American AND passenger
# 1505 United AND flight
# 1506 United AND passenger
# 1507 Qatar Airways
# 1508 Etihad NOT Manchester City
# 1509 Qatar AND flight
# 1510 Qatar AND passenger
# 1511 Emirates AND flight
# 1512 Emirates AND passenger
# 1513 IATA
# 1514 American Airlines
# 1515 Emirates AND airline
# 1516 Emirates AND airlines
# 1517 Qatar AND airline
# 1518 Qatar AND airlines
# 1519 United AND airline
# 1520 United AND airlines
# 1521 Air France
# 1522 GOL AND airline
# 1523 GOL AND airlines
# 1524 Korean Air
# 1525 airline AND regulat
# 1526 aviat AND regulat
# 1527 aircraft AND regulat
# 1528 airline AND environment
# 1529 aviat AND environment
# 1530 airline AND safet
# 1531 aviat AND safet
# 1532 Wyndham NOT Theatre NOT Theater NOT Herald NOT Vale NOT Star Weekly NOT Wyndham Clark NOT Wyndham Street NOT Wyndham Drive NOT Lucy Wyndham NOT Wyndham Manor NOT Wyndham Council NOT Wyndham Lakes
# 1533 Airbus
# 1534 Embraer
# 1535 Boeing
# 1536 Honeywell
# 1537 Fleury
# 1538 American Express
# 1539 Dassault
# 1540 wyndham
# 1541 Honeywell AND engine
# 1542 Honeywell AND engine AND aircraft
# 1543 VERITAS
# 1544 airline AND UK
# 1545 airline AND United Kingdom
# 1546 airline AND United Kingdom
# 1547 airlines AND UK
# 1548 airlines AND British
# 1549 airlines AND United Kingdom
# 1550 airlines AND United Kingdom
# 1551 airport AND UK
# 1552 airport AND British
# 1553 airport AND United Kingdom
# 1554 airport AND United Kingdom
# 1555 air traffic AND UK
# 1556 air traffic AND British
# 1557 air traffic AND United Kingdom
# 1558 business AND airport
# 1559 ICAO
# 1560 Airbus AND C295
# 1561 Embraer AND Honeywell
# 1562 Embraer
# 1563 Airbus AND Helicopter
# 1564 Phnom Penh AND Airport
# 1565 Honeywell
# 1566 DEFIANT X
# 1567 A320neo AND engine
# 1568 Dassault
# 1569 United Airlines AND cargo
# 1570 American Airlines AND cargo
# 1571 Air France AND cargo
# 1572 air cargo
# 1573 airline AND cargo
# 1574 Hawaiian airlines
# 1575 pilot training
# 1576 Accor
# 1577 Wyndham
# 1578 Marriott
# 1579 accor
# 1580 ihg
# 1581 hyatt
# 1582 starwood
# 1583 travel AND executive
# 1584 hotel AND executive
# 1585 SAAB NOT Elie Saab
# 1586 Kongsberg
# 1587 IHG
# 1588 Marriott
# 1589 Accor
# 1590 Wyndham
# 1591 RitzCarlton
# 1592 IHG
# 1593 starwood
# 1594 starwood
# 1595 Embraer
# 1596 Airbnb
# 1597 Aviation fuel
# 1598 Pertamina
# 1599 American AND flight
# 1600 American AND passenger
# 1601 American AND aircraft
# 1602 United AND flight
# 1603 United AND passenger
# 1604 United AND aircraft
# 1605 Qatar Airways
# 1606 Etihad NOT Manchester City
# 1607 Qatar AND flight
# 1608 Qatar AND passenger
# 1609 Qatar AND aircraft
# 1610 Emirates AND flight
# 1611 Emirates AND passenger
# 1612 Emirates AND aircraft
# 1613 IATA
# 1614 Starwood
# 1615 Westin
# 1616 westin AND hotel
# 1617 St Regis
# 1618 W Hotel
# 1619 st regis AND hotel
# 1620 Accor
# 1621 Wyndham
# 1622 IHG
# 1623 Hyatt NOT Farber NOT Aundre Hyatt NOT Mitch Hyatt NOT Andy Hyatt NOT Andrew Hyatt NOT Jalin Hyatt NOT Michael Hyatt NOT Melissa Hyatt NOT Hyatt Gun Shop NOT Larry Hyatt NOT Karen Hyatt NOT Spencer Hyatt NOT Kyle Hyatt NOT Kim Hyatt NOT Rohail Hyatt NOT Brownstein Hyatt
# 1624 Airbnb
# 1625 Marriott International
# 1626 Marriott International
# 1627 Marriott International NOT PRNewswire
# 1628 Marriott International NOT PRNewswire
# 1629 Marriott NOT Jack Marriott NOT Christina Marriott NOT Anna Marriott
# 1630 Westin NOT David Westin NOT Sherrie Westin
# 1631 westin AND hotel
# 1632 RitzCarlton
# 1633 St Regis NOT St Regis Falls NOT Mohawk
# 1634 W Hotel
# 1635 American Airlines
# 1636 Emirates AND airline
# 1637 Emirates AND airlines
# 1638 Qatar AND airline
# 1639 Qatar AND airlines
# 1640 United AND airline
# 1641 United AND airlines
# 1642 Air France
# 1643 GOL AND airline
# 1644 GOL AND airlines
# 1645 Korean Air
# 1646 airline AND environment
# 1647 aviat AND environment
# 1648 aircraft AND environment
# 1649 airline AND safet
# 1650 aviat AND safet
# 1651 aircraft AND safet
# 1652 Accor
# 1653 Mandarin Oriental
# 1654 Wyndham NOT Theatre NOT Theater NOT Herald NOT Vale NOT Star Weekly NOT Wyndham Clark NOT Wyndham Street NOT Wyndham Drive NOT Lucy Wyndham NOT Wyndham Manor NOT Wyndham Council NOT Wyndham Lakes
# 1655 Airbus
# 1656 Embraer
# 1657 Boeing
# 1658 Honeywell
# 1659 Destination AND hotel AND hyatt
# 1660 Destination AND resort AND hyatt
# 1661 Destination AND hotels AND hyatt
# 1662 Destination AND resorts AND hyatt
# 1663 Fleury
# 1664 American Express
# 1665 Marriott Bonvoy
# 1666 Marriott AND Bonvoy
# 1667 American Express
# 1668 American Express
# 1669 Digital AND health AND partnership
# 1670 Dassault
# 1671 Sustainability AND corporate
# 1672 wyndham
# 1673 American Express
# 1674 Honeywell AND engine
# 1675 Honeywell AND engine AND aircraft
# 1676 health AND predict AND AI
# 1677 Marriott International
# 1678 VERITAS
# 1679 airline AND UK
# 1680 airlines AND UK
# 1681 airport AND UK
# 1682 airport AND British
# 1683 air traffic AND UK
# 1684 air traffic AND British
# 1685 ICAO
# 1686 Honeywell
# 1687 Kongsberg AND Airbus
# 1688 Airbus AND C295
# 1689 Embraer AND Honeywell
# 1690 Embraer
# 1691 Airbus AND Helicopter
# 1692 Phnom Penh AND Airport
# 1693 Honeywell
# 1694 DEFIANT X
# 1695 Four seasons AND hotel
# 1696 Rosewood AND Hotel
# 1697 Starwood
# 1698 Airbus
# 1699 Boeing
# 1700 Embraer
# 1701 airbus helicopters
# 1702 C295
# 1703 Air Canada
# 1704 A220
# 1705 American Airlines
# 1706 United Airlines
# 1707 Hawaiian Airlines
# 1708 Airbus
# 1709 A220
# 1710 Boeing
# 1711 Embraer
# 1712 Airbus AND helicopter
# 1713 C295
# 1714 AirAsia
# 1715 Air France
# 1716 British Airways
# 1717 IATA
# 1718 Boeing AND Helicopter
# 1719 Hyatt
# 1720 pertamina
# 1721 A320neo AND engine
# 1722 American Express AND business AND credit
# 1723 Dassault
# 1724 Sarah Derry AND Accor
# 1725 American Airlines AND cargo
# 1726 Air France AND cargo
# 1727 air cargo
# 1728 pilot training
# 1729 Marriott
# 1730 accor
# 1731 ihg
# 1732 hyatt
# 1733 travel AND executive
# 1734 hotel AND executive
# 1735 American AND aircraft
# 1736 United AND aircraft
# 1737 Qatar AND aircraft
# 1738 Emirates AND aircraft
# 1739 aircraft AND environment
# 1740 aircraft AND safet
# 1741 Wyndham NOT Theatre NOT Theater NOT Herald NOT Vale NOT Star Weekly NOT Wyndham Clark NOT Wyndham Street NOT Wyndham Drive NOT Lucy Wyndham NOT Wyndham Manor NOT Wyndham Council NOT Wyndham Lakes
# 1742 Airbus
# 1743 Embraer
# 1744 Boeing
# 1745 GM AND autonomous
# 1746 Honeywell AND aerospace
# 1747 AI AND Media
# 1748 sustainability AND technology
# 1749 Honeywell
# 1750 Fleury
# 1751 American Express
# ...
# 8434 Acura AND vehicle
# 8435 Acura AND vehicle
# 8436 Ford AND auto
# 8437 Ford AND vehicle
# 8438 Honda AND auto
# 8439 Honda AND auto
# 8440 Honda AND vehicle
# 8441 Jaguar AND auto
# 8442 Jaguar AND auto
# 8443 Jaguar AND vehicle
# 8444 Jaguar AND vehicle
# 8445 MercedesBenz AND auto
# 8446 MercedesBenz AND auto
# 8447 MercedesBenz AND vehicle
# 8448 MercedesBenz AND vehicle
# 8449 Perfluorooctanoic Acid
# 8450 Perfluorooctanoic Acid
# 8451 blood test
# 8452 blood test
# 8453 BristolMyers Squibb
# 8454 Bristol Myers
# 8455 3M AND Per and Polyfluoroalkyl Substances
# 8456 3M AND Per and Polyfluoroalkyl Substances
# 8457 3M AND Perfluorooctanoic Acid
# 8458 3M AND Perfluorooctanoic Acid
# 8459 Apple AND health
# 8460 Apple AND medicine
# 8461 Apple AND medicine
# 8462 Apple AND drug
# 8463 Apple AND drug
# 8464 Apple AND hospital
# 8465 Apple AND hospital
# 8466 Bristol Myers Squibb
# 8467 Bristol Myers Squibb
# 8468 SaintGobain
# 8469 SaintGobain
# 8470 EPA NOT fish oil NOT DHA
# 8471 JPMorgan AND covid
# 8472 JPMorgan AND covid
# 8473 JPMorgan AND covid
# 8474 Chase AND business AND credit
# 8475 Chase AND business AND credit
# 8476 Chase AND business AND credit
# 8477 JPMorgan AND business AND credit
# 8478 JPMorgan AND business AND credit
# 8479 JPMorgan AND business AND credit
# 8480 Bristol Myers Squibb
# 8481 Bristol Myers Squibb
# 8482 JPMorgan AND credit card
# 8483 JPMorgan AND credit card
# 8484 Apple AND drugs
# 8485 Apple AND drugs
# 8486 3M AND PFAS
# 8487 3M AND PFAS
# 8488 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8489 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8490 blood test
# 8491 blood test
# 8492 3M AND PFAS
# 8493 3M AND PFAS
# 8494 3M NOT 3M ago
# 8495 blood test AND cancer
# 8496 PFAS
# 8497 3M AND PFOS
# 8498 3M AND PFOS
# 8499 3M AND Pollution
# 8500 3M AND Pollution
# 8501 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8502 Per and Polyfluoroalkyl Substances
# 8503 3M AND PFAS
# 8504 3M AND Per and Polyfluoroalkyl Substances
# 8505 3M NOT 3M ago
# 8506 blood tests AND cancer
# 8507 PFAS
# 8508 PFAS
# 8509 convenience stores
# 8510 Regulation AND Car
# 8511 3M NOT 3M ago
# 8512 3M NOT 3M ago
# 8513 natural gas AND vehicles
# 8514 natural gas AND fleet
# 8515 natural gas AND infrastructure
# 8516 compressed natural gas
# 8517 California AND natural gas AND production
# 8518 EPA AND methane
# 8519 EPA AND emissions
# 8520 EPA AND regulations
# 8521 climate change AND natural gas
# 8522 sustainability AND technology
# 8523 Target AND store
# 8524 Diesel AND Emissions
# 8525 vehicle AND legislat
# 8526 emissions AND legislation
# 8527 Target AND store
# 8528 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8529 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8530 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8531 Per and Polyfluoroalkyl Substances
# 8532 Per and Polyfluoroalkyl Substances
# 8533 Per and Polyfluoroalkyl Substances
# 8534 regulation AND PFAS
# 8535 regulation AND Per and Polyfluoroalkyl Substances
# 8536 EPA AND PFAS
# 8537 EPA AND PFAS
# 8538 EPA AND PFAS
# 8539 EPA AND Per and Polyfluoroalkyl Substances
# 8540 EPA AND Per and Polyfluoroalkyl Substances
# 8541 EPA AND Per and Polyfluoroalkyl Substances
# 8542 emissions AND regulations
# 8543 emissions AND regulatory
# 8544 emissions AND legislation
# 8545 PFAS
# 8546 PFAS
# 8547 environmental justice
# 8548 environmental justice
# 8549 investors AND protection
# 8550 ESG AND invest AND climate
# 8551 ESG AND invest AND climate
# 8552 Environmental Justice
# 8553 esg AND technology
# 8554 3M AND earplugs
# 8555 3M NOT 3M ago
# 8556 The Sportsman
# 8557 The Sportsman
# 8558 chemicals AND environment
# 8559 veterinarian
# 8560 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8561 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8562 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8563 Per and Polyfluoroalkyl Substances
# 8564 Per and Polyfluoroalkyl Substances
# 8565 Per and Polyfluoroalkyl Substances
# 8566 3M AND PFAS
# 8567 3M AND Per and Polyfluoroalkyl Substances
# 8568 PFAS
# 8569 PFAS
# 8570 honeywell
# 8571 Honeywell
# 8572 3M AND COVID
# 8573 3M AND COVID
# 8574 3M AND COVID19
# 8575 3M AND COVID19
# 8576 3M AND coronavirus
# 8577 3M AND pandemic
# 8578 3M AND pandemic
# 8579 Honeywell
# 8580 3M NOT 3M ago
# 8581 Honeywell
# 8582 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8583 EPA AND PFAS
# 8584 AFFF
# 8585 PFAS
# 8586 Per and Polyfluoroalkyl Substances
# 8587 Congress AND PFAS
# 8588 Congress AND Per and Polyfluoroalkyl Substances
# 8589 Clean Water Act
# 8590 PFAS
# 8591 Cancer AND app
# 8592 food AND labels
# 8593 chemicals AND environment
# 8594 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8595 Per and Polyfluoroalkyl Substances
# 8596 regulation AND PFAS
# 8597 regulation AND Per and Polyfluoroalkyl Substances
# 8598 FDA AND PFAS
# 8599 FDA AND Per and Polyfluoroalkyl Substances
# 8600 Congress AND PFAS
# 8601 Congress AND Per and Polyfluoroalkyl Substances
# 8602 cosmetics AND regulation
# 8603 skincare AND regulation
# 8604 PFAS
# 8605 environment AND bottles
# 8606 plastic AND bottles
# 8607 chemicals AND emissions
# 8608 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8609 EPA AND PFAS
# 8610 Perfluorooctanoic Acid
# 8611 general mills
# 8612 general mills
# 8613 substance abuse
# 8614 general mills
# 8615 Best Buy
# 8616 Best Buy
# 8617 General Mills
# 8618 General Mills
# 8619 General Mills
# 8620 General Mills
# 8621 General Mills
# 8622 General Mills
# 8623 Diversity AND business
# 8624 Diversity and Inclusion
# 8625 disability
# 8626 disability
# 8627 disabled
# 8628 disabled
# 8629 unemployment
# 8630 disparities AND screening
# 8631 disparities AND screening
# 8632 disparities AND screening
# 8633 Cargill
# 8634 Cargill
# 8635 Cargill
# 8636 Cargill
# 8637 General Mills
# 8638 General Mills
# 8639 General Mills
# 8640 General Mills
# 8641 3M NOT 3M ago
# 8642 3M NOT 3M ago
# 8643 3M NOT 3M ago
# 8644 Unemployment rate
# 8645 Unemployment rate
# 8646 Unemployment rate
# 8647 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8648 Per and Polyfluoroalkyl Substances
# 8649 Lawsuit AND PFAS
# 8650 Lawsuit AND Per and Polyfluoroalkyl Substances
# 8651 American Express
# 8652 American Express AND small business
# 8653 banking AND workplace
# 8654 bank AND workplace
# 8655 Visa
# 8656 American Express
# 8657 Fiserv
# 8658 Mike Roman AND 3M
# 8659 Mike Roman AND 3M
# 8660 3M AND pandemic
# 8661 3M AND pandemic
# 8662 Membrana AND 3M
# 8663 American Express
# 8664 Visa NOT work visa NOT exit visa NOT visa entry NOT student visa NOT travel visa NOT visa waiver NOT tourist visa NOT visa restrictions NOT health and care visa NOT pilgrimage visa NOT NHS visa NOT immigration AND Europe
# 8665 Visa AND North America
# 8666 Visa AND North America
# 8667 Amex AND North America
# 8668 American Express AND North America
# 8669 American Express AND North America
# 8670 3M NOT 3M ago
# 8671 3M NOT 3M ago
# 8672 3M NOT 3m
# 8673 chemicals AND environment
# 8674 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8675 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8676 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8677 Per and Polyfluoroalkyl Substances
# 8678 Per and Polyfluoroalkyl Substances
# 8679 Per and Polyfluoroalkyl Substances
# 8680 regulation AND PFAS
# 8681 regulation AND PFAS
# 8682 regulation AND PFAS
# 8683 regulation AND PFAS
# 8684 regulation AND Per and Polyfluoroalkyl Substances
# 8685 regulation AND Per and Polyfluoroalkyl Substances
# 8686 regulation AND Per and Polyfluoroalkyl Substances
# 8687 regulation AND Per and Polyfluoroalkyl Substances
# 8688 PFAS Action Plan
# 8689 PFAS
# 8690 PFAS
# 8691 Propel AND Water
# 8692 National Institutes of Health
# 8693 Kidney cancer
# 8694 Kidney cancer
# 8695 Kidney cancer
# 8696 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8697 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8698 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8699 Per and Polyfluoroalkyl Substances
# 8700 Per and Polyfluoroalkyl Substances
# 8701 Per and Polyfluoroalkyl Substances
# 8702 PFAS
# 8703 PFAS
# 8704 Amazon AND home AND design
# 8705 Perfluorooctane Sulfonate
# 8706 Perfluorooctane Sulfonate
# 8707 Perfluorooctanoic Acid
# 8708 Perfluorooctanoic Acid
# 8709 PFOA
# 8710 f35
# 8711 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8712 Perfluorooctane Sulfonate
# 8713 Perfluorooctane Sulfonate
# 8714 Perfluorooctanoic Acid
# 8715 Perfluorooctanoic Acid
# 8716 F35 AND Training
# 8717 F35 AND Training
# 8718 Water AND Environmental Protection Agency
# 8719 Water AND Environmental Protection Agency
# 8720 PFAS
# 8721 PFAS
# 8722 PFOA
# 8723 PFOA
# 8724 fiber AND trends
# 8725 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8726 regulation AND PFAS
# 8727 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8728 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8729 PFAS
# 8730 PFAS
# 8731 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8732 regulation AND PFAS
# 8733 microplastics
# 8734 3M AND COVID
# 8735 3M NOT 3M ago
# 8736 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8737 EPA AND PFAS
# 8738 AFFF
# 8739 EPA NOT fish oil NOT DHA
# 8740 PFAS
# 8741 PFAS
# 8742 space force
# 8743 Space Force
# 8744 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8745 Per and Polyfluoroalkyl Substances
# 8746 EPA AND PFAS
# 8747 EPA AND Per and Polyfluoroalkyl Substances
# 8748 AFFF
# 8749 contaminat AND groundwater
# 8750 PFAS
# 8751 PFAS
# 8752 EPA
# 8753 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8754 Per and Polyfluoroalkyl Substances
# 8755 EPA AND PFAS
# 8756 EPA AND Per and Polyfluoroalkyl Substances
# 8757 environmental protection agency
# 8758 Energy AND Environmental Protection Agency
# 8759 EPA NOT fish oil NOT DHA
# 8760 PFAS
# 8761 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8762 Per and Polyfluoroalkyl Substances
# 8763 blood test
# 8764 PFAS
# 8765 PFAS
# 8766 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8767 regulation AND PFAS
# 8768 environmental protection agency
# 8769 Water AND Environmental Protection Agency
# 8770 Water AND Environmental Protection Agency
# 8771 PFAS
# 8772 PFAS
# 8773 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8774 COVID19 testing AND airport
# 8775 PFAS
# 8776 PFAS
# 8777 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8778 PFAS
# 8779 PFAS
# 8780 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8781 PFAS
# 8782 PFAS
# 8783 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8784 PFAS
# 8785 PFAS
# 8786 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8787 PFAS
# 8788 PFAS
# 8789 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8790 PFAS
# 8791 PFAS
# 8792 BPA AND bisphenol A
# 8793 BPA AND bisphenol A
# 8794 BPA AND bisphenol A
# 8795 Plastic waste
# 8796 BPA AND plastics
# 8797 Bisphenol A
# 8798 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8799 Human AND Growth AND Foundation
# 8800 innovation AND finance
# 8801 risk management AND credit
# 8802 3M NOT 3M ago
# 8803 3M NOT 3M ago
# 8804 Personal Capital
# 8805 Personal Capital
# 8806 Personal Capital
# 8807 Electric AND Vehicle
# 8808 electric AND commercial AND vehicle
# 8809 electric AND Vehicle AND startup
# 8810 electric AND vehicle AND battery
# 8811 Tesla NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 8812 Ford AND Flex NOT Tom Ford NOT Doug Ford NOT Beth Ford NOT contact seller NOT Harrison Ford NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police NOT arson NOT theft
# 8813 auto industry
# 8814 BMW NOT Homicide NOT carjacking NOT car crash NOT gun attack NOT stolen car NOT vehicle crash NOT intoxicated NOT Robbery NOT Police AND speed NOT arson
# 8815 electric AND auto
# 8816 Ford AND Auto
# 8817 BMW AND auto
# 8818 BMW AND vehicle
# 8819 Ford AND auto
# 8820 Tesla AND auto
# 8821 3M NOT 3M ago
# 8822 Fidelity
# 8823 National Cancer Institute
# 8824 National Cancer Institute
# 8825 National Cancer Institute
# 8826 GMO
# 8827 EPA
# 8828 health AND legislat
# 8829 health AND legislat
# 8830 health AND reform
# 8831 health AND reform
# 8832 health AND reform
# 8833 Cancer
# 8834 health AND reform
# 8835 GMO
# 8836 GMO
# 8837 food AND Natural
# 8838 food AND Natural
# 8839 chemicals AND environment
# 8840 Newborn AND health
# 8841 GMO
# 8842 sugarcane AND market
# 8843 sugarcane AND market
# 8844 health AND reform
# 8845 health AND reform
# 8846 health AND reform
# 8847 health AND reform
# 8848 polyethylene AND produc
# 8849 polyethylene AND manufactur
# 8850 GMO AND food
# 8851 diagnos AND cancer
# 8852 test AND cancer
# 8853 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8854 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8855 EPA AND PFAS
# 8856 EPA AND PFAS
# 8857 consumers AND environmental
# 8858 consumers AND environmental
# 8859 EPA NOT fish oil NOT DHA
# 8860 PFAS
# 8861 PFAS
# 8862 supply chain
# 8863 CFA NOT are registered trademarks owned by CFA Institute NOT country fire authority NOT Evan Niu NOT francs NOT Canadian Federation of Agriculture NOT firefighter NOT Rohit Tuli NOT CFA and Chartered Financial Analyst are registered trademarks
# 8864 CFA NOT are registered trademarks owned by CFA Institute NOT country fire authority NOT Evan Niu NOT francs NOT Canadian Federation of Agriculture NOT firefighter NOT Rohit Tuli NOT CFA and Chartered Financial Analyst are registered trademarks
# 8865 Regulation AND Vehicle
# 8866 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8867 Lawsuit AND PFAS
# 8868 regulation AND PFAS
# 8869 EU AND PFAS
# 8870 3M AND PFAS
# 8871 3M NOT 3M ago
# 8872 PFAS
# 8873 PFAS
# 8874 securities AND regulatory
# 8875 investors AND regulation
# 8876 Square AND business AND credit
# 8877 finance AND regulation
# 8878 esg AND technology
# 8879 apartment AND storage
# 8880 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8881 AFFF
# 8882 PFAS
# 8883 PFAS
# 8884 3M NOT 3M ago
# 8885 3M NOT 3M Ago
# 8886 Cardiovascular Disease
# 8887 Orville Redenbachers
# 8888 Perfluorooctane Sulfonate
# 8889 Perfluorooctanoic Acid
# 8890 Diabetes
# 8891 Cleveland Clinic
# 8892 PFOA
# 8893 PFOA
# 8894 Packaging
# 8895 NonHodgkins lymphoma
# 8896 NonHodgkins lymphoma
# 8897 NonHodgkins lymphoma
# 8898 Hodgkins lymphoma
# 8899 Hodgkins lymphoma
# 8900 Hodgkins lymphoma
# 8901 DuPont AND chemical
# 8902 Hodgkins lymphoma
# 8903 NonHodgkins lymphoma
# 8904 Melanoma
# 8905 Melanoma
# 8906 nonHodgkin AND lymphoma
# 8907 nonHodgkin AND lymphoma
# 8908 nonhodgkins AND lymphoma
# 8909 nonhodgkins AND lymphoma
# 8910 nonhodgkins AND lymphoma
# 8911 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8912 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8913 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8914 Lawsuit AND PFAS
# 8915 Lawsuit AND PFAS
# 8916 Lawsuit AND PFAS
# 8917 Lawsuit AND PFAS
# 8918 regulator AND PFAS
# 8919 DuPont AND PFAS
# 8920 DuPont AND PFAS
# 8921 DuPont AND PFAS
# 8922 DuPont AND PFAS
# 8923 3M AND PFAS
# 8924 3M AND PFAS
# 8925 3M NOT 3M ago
# 8926 Dupont
# 8927 Dupont
# 8928 PFAS
# 8929 PFAS
# 8930 rail AND safety
# 8931 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators
# 8932 Offshore AND Wind AND Farm
# 8933 Offshore AND Wind AND Farm
# 8934 Superfund
# 8935 Superfund
# 8936 PFAS
# 8937 PFAS
# 8938 CFA NOT are registered trademarks owned by CFA Institute NOT country fire authority NOT Evan Niu NOT francs NOT Canadian Federation of Agriculture NOT firefighter NOT Rohit Tuli NOT CFA and Chartered Financial Analyst are registered trademarks
# 8939 health AND regulat
# 8940 Safety AND Vehicle NOT manslaughter NOT murder NOT homicide NOT robbery NOT carjacking
# 8941 Regulation AND Vehicle
# 8942 retail AND health care
# 8943 analytics AND health care
# 8944 retail AND health care
# 8945 retail AND health care
# 8946 analytics AND health care
# 8947 vehicle AND regulat
# 8948 vehicle AND lawsuit
# 8949 vehicle AND policy
# 8950 vehicle AND policies
# 8951 PFAS NOT Pension Fund Administrator NOT Pension Fund Administrators

# %%
# run a new search
term_idx = 1
nbr_results_to_return = int(25) # need to limit results, otherwise all docs in corpus will be returned
result = pipe.run(
    query=searches[term_idx],
    params={"top_k": nbr_results_to_return}
)

# compile search results with ad predictions
search_results = pd.DataFrame({
    "search_term": searches[term_idx],
    "doc_id": [doc.meta['doc_id'] for doc in result['documents']],
    "text": [doc.content for doc in result['documents']],
    "score_search": [doc.score for doc in result['documents']],
    "score_ad_prob": [ad_probs_of_doc_ids_in_cluster_samples[int(doc.meta['doc_id'])] for doc in result['documents']],
    "original_disposition": [
        blackwing_data.loc[blackwing_data['doc_id'] == int(doc.meta['doc_id']), 'disposition'].values.tolist()[0] 
        for doc in result['documents']
    ],
})
search_results['score_final'] = search_results['score_search'] * (1 - search_results['score_ad_prob'])

search_results.sort_values(['score_search'], ascending=False).to_csv(f'test_results_option1_search{term_idx}.csv', index=False)
search_results.head()
# Out:
#         search_term doc_id  \
# 0  General Electric   5432
# 1  General Electric   8283
# 2  General Electric   4444
# 3  General Electric   3314
# 4  General Electric   5432
#
#                                                                               text  \
# 0  ?While we do not always begin our journey with perfect information we strive...
# 1  Feb 16 (Reuters) - CelLink a California startup with a pathbreaking product ...
# 2  It hasn?t followed many industrial peers most recently General Electric Co. ...
# 3  He found many supporters for his project such as ?MIT? ?Honeywell? and ?Gene...
# 4  said Chad McAllister executive vice president Milliken & Company and preside...
#
#    score_search  score_ad_prob original_disposition  score_final
# 0      0.649902       0.462885               SELECT     0.349072
# 1      0.649149       0.275130               SELECT     0.470548
# 2      0.648335       0.878326               SELECT     0.078886
# 3      0.648176       0.884746               IGNORE     0.074705
# 4      0.648093       0.462885               SELECT     0.348100

# %% [markdown]
# #### Output Option 2
#
# Original search from Blackwing, just de-duplicated syndicated content and sorted by ad probability.

# %%
blackwing_data['ad_probability'] = blackwing_data['cluster'].map(cluster_ad_probs)
blackwing_data.sort_values(['ad_probability', 'doc_id']).to_csv('test_results_option2.csv', index=False)
